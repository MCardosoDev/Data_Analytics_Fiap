# %% [markdown]
# ## Predizendo a evasão de alunos(as) e sucesso acadêmico
#
# ### Sobre a base de dados:
#
# Um conjunto de dados criado a partir de uma instituição de ensino superior (adquirido de várias bases de dados disjuntas) relacionado a alunos matriculados em diferentes cursos de graduação, como agronomia, design, educação, enfermagem, jornalismo, administração, serviço social e tecnologias. O conjunto de dados inclui informações conhecidas no momento da matrícula do aluno (percurso acadêmico, demografia e fatores socioeconômicos) e o desempenho acadêmico do aluno no final do primeiro e segundo semestres. Os dados são usados ​​para construir modelos de classificação para prever a evasão e o sucesso acadêmico dos alunos. O problema é formulado como uma tarefa de classificação de três categorias, na qual há um forte desequilíbrio em relação a uma das classes.
#
# Para qual finalidade o conjunto de dados foi criado?
#
# O conjunto de dados foi criado no âmbito de um projeto que visa contribuir para a redução do abandono e insucesso académico no ensino superior, através da utilização de técnicas de aprendizagem automática para identificar alunos em risco numa fase inicial do seu percurso académico, de modo a que estratégias de apoio aos mesmos possam ser postas em prática. O conjunto de dados inclui informações conhecidas no momento da matrícula do aluno – trajetória acadêmica, demografia e fatores socioeconômicos. O problema é formulado como uma tarefa de classificação de três categorias (abandono, matriculado e graduado) ao final da duração normal do curso.
#
# ### Sobre a fonte de dados:
#
# Este conjunto de dados é apoiado pelo programa SATDAP - Capacitação da Administração Pública ao abrigo da bolsa POCI-05-5762-FSE-000191, Portugal.
#
# ### Tratamento dos dados:
#
# Foi realizado um pré-processamento de dados rigoroso para lidar com dados de anomalias, outliers inexplicáveis ​​e valores ausentes.
#
# Link: https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success

# %% [markdown]
# ### Dicionários dos dados:
#
# **Estado civil:** 1 – solteiro 2 – casado 3 – viúvo 4 – divorciado 5 – união de fato 6 – separado judicialmente
#
# **Curso:** 33 - Tecnologias de Produção de Biocombustíveis 171 - Design de Animação e Multimédia 8014 - Serviço Social (prestação nocturna) 9003 - Agronomia 9070 - Design de Comunicação 9085 - Enfermagem Veterinária 9119 - Engenharia Informática 9130 - Equincultura 9147 - Gestão 9238 - Serviço Social 9254 - Turismo 9500 - Enfermagem 9556 - Higiene Oral 9670 - Gestão de Publicidade e Marketing 9773 - Jornalismo e Comunicação 9853 - Ensino Básico 9991 - Gestão (presencial noturno).
#
#
# **Qualificação anterior:** 1 - Ensino secundário 2 - Ensino superior - licenciatura 3 - Ensino superior - licenciatura 4 - Ensino superior - mestrado 5 - Ensino superior - doutoramento 6 - Frequência do ensino superior 9 - 12.º ano de escolaridade - não concluído 10 - 11.º ano de escolaridade - não concluído 12 - Outro - 11º ano de escolaridade 14 - 10º ano de escolaridade 15 - 10º ano de escolaridade - não concluído 19 - Ensino básico 3º ciclo (9º/10º/11º ano) ou equiv. 38 - Ensino básico 2º ciclo (6º/7º/8º ano) ou equiv. 39 - Curso de especialização tecnológica 40 - Ensino superior - licenciatura (1º ciclo) 42 - Curso técnico superior profissional 43 - Ensino superior - mestrado (2º ciclo)
#
# **Qualificação anterior (grau):** Nota da qualificação anterior (entre 0 e 200)
#
# **Nacionalidade:** 1 - Português; 2 - Alemão; 6 - Espanhol; 11 - Italiano; 13 - holandês; 14 - Inglês; 17 - lituano; 21 - angolano; 22 - cabo-verdiana; 24 - Guineense; 25 - moçambicano; 26 - Santomense; 32 - turco; 41 - Brasileiro; 62 - romeno; 100 - Moldávia (República da); 101 - Mexicana; 103 - Ucraniano; 105 - russo; 108 - cubano; 109 - Colombiano
#
# **Nota de admissão:** Nota de admissão (entre 0 e 200)
#
# **Necessidades educacionais especiais:** 1 – sim 0 – não
#
# **Devedor:** 1 – sim 0 – não
#
# **Mensalidades em dia:** 1 – sim 0 – não
#
# **Gênero:** 1 – masculino 0 – feminino
#
# **Bolsista:** 1 – sim 0 – não
#
# **Internacional:** 1 – sim 0 – não
#
# **Unidades curriculares 1º semestre (creditado):** Número de unidades curriculares creditadas no 1º semestre
#
# **Unidades curriculares 1º semestre (inscrito):** Número de unidades curriculares inscritas no 1.º semestre
#
# **Unidades curriculares 1º semestre (avaliações):** Número de avaliações a unidades curriculares no 1º semestre
#
# **Unidades curriculares 1º semestre (aprovado):** Número de unidades curriculares aprovadas no 1.º semestre:
#
# **Unidades curriculares 1º semestre (grau):** Média de notas no 1º semestre (entre 0 e 20)
#
# **Unidades curriculares 1º semestre (sem avaliações):** Número de unidades curriculares sem avaliações no 1º semestre
#
# **Unidades curriculares 2º semestre (creditado):** Número de unidades curriculares creditadas no 2º semestre
#
# **Unidades curriculares 2º semestre (inscrito):** Número de unidades curriculares inscritas no 2.º semestre
#
# **Unidades curriculares 2º semestre (avaliações):** Número de avaliações a unidades curriculares no 2º semestre
#
# **Unidades curriculares 2º semestre (aprovado):** Número de unidades curriculares aprovadas no 2.º semestre
#
# **Unidades curriculares 2º semestre (grau):** Média de notas no 2º semestre (entre 0 e 20)
#
# **Unidades curriculares 2º semestre (sem avaliações):** Número de unidades curriculares sem avaliações no 1º semestre
#
# **Taxa de desemprego:** Taxa de desemprego (%)
#
# **Taxa de inflação:** Taxa de inflação (%)
#
# **PIB**: PIB
#
# **Target**: Alvo. O problema é formulado como uma tarefa de classificação de três categorias (abandono, matriculado e graduado) ao final da duração normal do curso

# %%
#! pip install pandas==1.3.5
#! pip install scikit-learn==1.0.2
#! pip install joblib>=0.11,<=1.0.1
#! pip install scikit-learn==1.2.2

# %% [markdown]
# ## Tratamento dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("PredictStudentStatus.xlsx")
df.head()
# Out:
#    Marital status  Course  Previous qualification  \
# 0               1     171                       1
# 1               1    9254                       1
# 2               1    9070                       1
# 3               1    9773                       1
# 4               2    8014                       1
#
#    Previous qualification (grade)  Nacionality  Admission grade  \
# 0                           122.0            1            127.3
# 1                           160.0            1            142.5
# 2                           122.0            1            124.8
# 3                           122.0            1            119.6
# 4                           100.0            1            141.5
#
#    Educational special needs  Debtor  Tuition fees up to date  Gender  ...  \
# 0                          0       0                        1       1  ...
# 1                          0       0                        0       1  ...
# 2                          0       0                        0       1  ...
# 3                          0       0                        1       0  ...
# 4                          0       0                        1       0  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                      0.000000e+00
# 1                                    6                      1.366667e+16
# 2                                    0                      0.000000e+00
# 3                                    5                      1.240000e+01
# 4                                    6                      1.300000e+01
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 28 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Course                                          4424 non-null   int64
#  2   Previous qualification                          4424 non-null   int64
#  3   Previous qualification (grade)                  4424 non-null   float64
#  4   Nacionality                                     4424 non-null   int64
#  5   Admission grade                                 4424 non-null   float64
#  6   Educational special needs                       4424 non-null   int64
#  7   Debtor                                          4424 non-null   int64
#  8   Tuition fees up to date                         4424 non-null   int64
#  9   Gender                                          4424 non-null   int64
#  10  Scholarship holder                              4424 non-null   int64
#  11  International                                   4424 non-null   int64
#  12  Curricular units 1st sem (credited)             4424 non-null   int64
#  13  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  14  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  15  Curricular units 1st sem (approved)             4424 non-null   int64
#  16  Curricular units 1st sem (grade)                4424 non-null   float64
#  17  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  18  Curricular units 2nd sem (credited)             4424 non-null   int64
#  19  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  20  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  21  Curricular units 2nd sem (approved)             4424 non-null   int64
#  22  Curricular units 2nd sem (grade)                4424 non-null   float64
#  23  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  24  Unemployment rate                               4424 non-null   float64
#  25  Inflation rate                                  4424 non-null   float64
#  26  GDP                                             4424 non-null   float64
#  27  Target                                          4424 non-null   object
# dtypes: float64(7), int64(20), object(1)
# memory usage: 967.9+ KB

# %%
df.shape
# Out:
# (4424, 28)

# %%
df.rename(columns={'Marital status': 'EstadoCivil',
                   'Course': 'Curso',
                   'Previous qualification':'QualificacaoAnterior',
                   'Previous qualification (grade)':'QualificacaoAnteriorGrau',
                   'Nacionality':'Nacionalidade',
                   'Admission grade':'NotaAdmissao',
                   'Educational special needs':'NecessidadesEspeciais',
                   'Debtor':'Devedor',
                   'Tuition fees up to date':'MensalidadesEmDia',
                   'Gender':'Genero',
                   'Scholarship holder':'Bolsista',
                   'Curricular units 1st sem (credited)':'UnidadesCurriculares1SemestreCreditado',
                   'Curricular units 1st sem (enrolled)':'UnidadesCurriculares1SemestreInscrito',
                   'Curricular units 1st sem (evaluations)':'UnidadesCurriculares1SemestreAvaliacoes',
                   'Curricular units 1st sem (approved)':'UnidadesCurriculares1SemestreAprovado',
                   'Curricular units 1st sem (grade)':'UnidadesCurriculares1SemestreGrau',
                   'Curricular units 1st sem (without evaluations)':'UnidadesCurriculares1SemestreSemAvaliacoes',
                   'Curricular units 2nd sem (credited)':'UnidadesCurriculares2SemestreCreditado',
                   'Curricular units 2nd sem (enrolled)':'UnidadesCurriculares2SemestreInscrito',
                   'Curricular units 2nd sem (evaluations)':'UnidadesCurriculares2SemestreAvaliacoes',
                   'Curricular units 2nd sem (approved)':'UnidadesCurriculares2SemestreAprovado',
                   'Curricular units 2nd sem (grade)':'UnidadesCurriculares2SemestreGrau',
                   'Curricular units 2nd sem (without evaluations)':'UnidadesCurriculares2SemestreSemAvaliacoes',
                   'Unemployment rate':'TaxaDesemprego',
                   'Inflation rate': 'TaxaInflacao',
                   'GDP':'PIB'
                  }, inplace=True)

# %%
df.head()
# Out:
#    EstadoCivil  Curso  QualificacaoAnterior  QualificacaoAnteriorGrau  \
# 0            1    171                     1                     122.0
# 1            1   9254                     1                     160.0
# 2            1   9070                     1                     122.0
# 3            1   9773                     1                     122.0
# 4            2   8014                     1                     100.0
#
#    Nacionalidade  NotaAdmissao  NecessidadesEspeciais  Devedor  \
# 0              1         127.3                      0        0
# 1              1         142.5                      0        0
# 2              1         124.8                      0        0
# 3              1         119.6                      0        0
# 4              1         141.5                      0        0
#
#    MensalidadesEmDia  Genero  ...  UnidadesCurriculares2SemestreCreditado  \
# 0                  1       1  ...                                       0
# 1                  0       1  ...                                       0
# 2                  0       1  ...                                       0
# 3                  1       0  ...                                       0
# 4                  1       0  ...                                       0
#
#    UnidadesCurriculares2SemestreInscrito  \
# 0                                      0
# 1                                      6
# 2                                      6
# 3                                      6
# 4                                      6
#
#    UnidadesCurriculares2SemestreAvaliacoes  \
# 0                                        0
# 1                                        6
# 2                                        0
# 3                                       10
# 4                                        6
#
#    UnidadesCurriculares2SemestreAprovado  UnidadesCurriculares2SemestreGrau  \
# 0                                      0                       0.000000e+00
# 1                                      6                       1.366667e+16
# 2                                      0                       0.000000e+00
# 3                                      5                       1.240000e+01
# 4                                      6                       1.300000e+01
#
#    UnidadesCurriculares2SemestreSemAvaliacoes  TaxaDesemprego  TaxaInflacao  \
# 0                                           0            10.8           1.4
# 1                                           0            13.9          -0.3
# 2                                           0            10.8           1.4
# 3                                           0             9.4          -0.8
# 4                                           0            13.9          -0.3
#
#     PIB    Target
# 0  1.74   Dropout
# 1  0.79  Graduate
# 2  1.74   Dropout
# 3 -3.12  Graduate
# 4  0.79  Graduate
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 28 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   EstadoCivil                                 4424 non-null   int64
#  1   Curso                                       4424 non-null   int64
#  2   QualificacaoAnterior                        4424 non-null   int64
#  3   QualificacaoAnteriorGrau                    4424 non-null   float64
#  4   Nacionalidade                               4424 non-null   int64
#  5   NotaAdmissao                                4424 non-null   float64
#  6   NecessidadesEspeciais                       4424 non-null   int64
#  7   Devedor                                     4424 non-null   int64
#  8   MensalidadesEmDia                           4424 non-null   int64
#  9   Genero                                      4424 non-null   int64
#  10  Bolsista                                    4424 non-null   int64
#  11  International                               4424 non-null   int64
#  12  UnidadesCurriculares1SemestreCreditado      4424 non-null   int64
#  13  UnidadesCurriculares1SemestreInscrito       4424 non-null   int64
#  14  UnidadesCurriculares1SemestreAvaliacoes     4424 non-null   int64
#  15  UnidadesCurriculares1SemestreAprovado       4424 non-null   int64
#  16  UnidadesCurriculares1SemestreGrau           4424 non-null   float64
#  17  UnidadesCurriculares1SemestreSemAvaliacoes  4424 non-null   int64
#  18  UnidadesCurriculares2SemestreCreditado      4424 non-null   int64
#  19  UnidadesCurriculares2SemestreInscrito       4424 non-null   int64
#  20  UnidadesCurriculares2SemestreAvaliacoes     4424 non-null   int64
#  21  UnidadesCurriculares2SemestreAprovado       4424 non-null   int64
#  22  UnidadesCurriculares2SemestreGrau           4424 non-null   float64
#  23  UnidadesCurriculares2SemestreSemAvaliacoes  4424 non-null   int64
#  24  TaxaDesemprego                              4424 non-null   float64
#  25  TaxaInflacao                                4424 non-null   float64
#  26  PIB                                         4424 non-null   float64
#  27  Target                                      4424 non-null   object
# dtypes: float64(7), int64(20), object(1)
# memory usage: 967.9+ KB

# %%
df.isnull().sum()
# Out:
# EstadoCivil                                   0
# Curso                                         0
# QualificacaoAnterior                          0
# QualificacaoAnteriorGrau                      0
# Nacionalidade                                 0
# NotaAdmissao                                  0
# NecessidadesEspeciais                         0
# Devedor                                       0
# MensalidadesEmDia                             0
# Genero                                        0
# Bolsista                                      0
# International                                 0
# UnidadesCurriculares1SemestreCreditado        0
# UnidadesCurriculares1SemestreInscrito         0
# UnidadesCurriculares1SemestreAvaliacoes       0
# UnidadesCurriculares1SemestreAprovado         0
# UnidadesCurriculares1SemestreGrau             0
# UnidadesCurriculares1SemestreSemAvaliacoes    0
# UnidadesCurriculares2SemestreCreditado        0
# UnidadesCurriculares2SemestreInscrito         0
# UnidadesCurriculares2SemestreAvaliacoes       0
# UnidadesCurriculares2SemestreAprovado         0
# UnidadesCurriculares2SemestreGrau             0
# UnidadesCurriculares2SemestreSemAvaliacoes    0
# TaxaDesemprego                                0
# TaxaInflacao                                  0
# PIB                                           0
# Target                                        0
# dtype: int64

# %%
df.head(3)
# Out:
#    EstadoCivil  Curso  QualificacaoAnterior  QualificacaoAnteriorGrau  \
# 0            1    171                     1                     122.0
# 1            1   9254                     1                     160.0
# 2            1   9070                     1                     122.0
#
#    Nacionalidade  NotaAdmissao  NecessidadesEspeciais  Devedor  \
# 0              1         127.3                      0        0
# 1              1         142.5                      0        0
# 2              1         124.8                      0        0
#
#    MensalidadesEmDia  Genero  ...  UnidadesCurriculares2SemestreCreditado  \
# 0                  1       1  ...                                       0
# 1                  0       1  ...                                       0
# 2                  0       1  ...                                       0
#
#    UnidadesCurriculares2SemestreInscrito  \
# 0                                      0
# 1                                      6
# 2                                      6
#
#    UnidadesCurriculares2SemestreAvaliacoes  \
# 0                                        0
# 1                                        6
# 2                                        0
#
#    UnidadesCurriculares2SemestreAprovado  UnidadesCurriculares2SemestreGrau  \
# 0                                      0                       0.000000e+00
# 1                                      6                       1.366667e+16
# 2                                      0                       0.000000e+00
#
#    UnidadesCurriculares2SemestreSemAvaliacoes  TaxaDesemprego  TaxaInflacao  \
# 0                                           0            10.8           1.4
# 1                                           0            13.9          -0.3
# 2                                           0            10.8           1.4
#
#     PIB    Target
# 0  1.74   Dropout
# 1  0.79  Graduate
# 2  1.74   Dropout
#
# [3 rows x 28 columns]

# %% [markdown]
# ## Conhecendo a base de dados
#
# Um passo muito importante no pipeline da construção de um modelo preditivo de machine learning é conhecer os dados. Como conhecemos os dados? Claro que análise exploratória dos dados pode ser uma ótima primeira largada!
#
# ### Para começar, vamos entender a nossa target?

# %%
set(df['Target'])
# Out:
# {'Dropout', 'Enrolled', 'Graduate'}

# %% [markdown]
# Próximo passo, vamos entender o equilíbrio da base de dados.

# %%
plt.figure(figsize=(8, 5))
df_targets = df.groupby('Target')['Target'].count()
df_targets.plot(kind='bar', color='lightgreen')

# Adicionar rótulos nas barras
for i, df_targets in enumerate(df_targets):
    plt.text(i, df_targets + 1, str(df_targets), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de categorias por status target')
plt.xlabel('Categorias')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %%
#Calcular o total de alunos(as) por tipo de status
df_targets_percent = df.groupby('Target')['Target'].count()

#Calcular a porcentagem de popularidade para cada álbum
total_estudantes = len(df)
df_target_porcentagem = df_targets_percent / total_estudantes * 100

#Separando os valores e nomes em uma lista, para deixar o gráfico mais apresentável
labels = df_target_porcentagem.index.tolist()
sizes = df_target_porcentagem.values.tolist()

#Criando o gráfico
figura, grafico = plt.subplots(figsize=(18, 6))
grafico.pie(sizes, autopct='%1.0f%%')
grafico.axis('equal')
plt.title('Porcentagem por status target')
plt.legend(labels, loc='best')
plt.show()

# %% [markdown]
# Inferências sobre os dados:
#
# Observamos que a maioria dos nossos dados estão classificados como "graduate".

# %% [markdown]
# ### Qual é o curso que possuí maior representação na amostra dos dados?

# %%
plt.figure(figsize=(8, 5))
df_courses = df.groupby('Curso')['Curso'].count().sort_values(ascending=False)
df_courses.plot(kind='bar', color='orange')

# Adicionar rótulos nas barras
for i, df_courses in enumerate(df_courses):
    plt.text(i, df_courses + 1, str(df_courses), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de estudantes por curso')
plt.xlabel('Curso')
plt.ylabel('Total Estudantes')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Inferência sobre os dados:
#
# Notas:
#
# 33 - Tecnologias de Produção de Biocombustíveis
#
# 171 - Design de Animação e Multimédia
#
# 8014 - Serviço Social (prestação nocturna)
#
# 9003 - Agronomia
#
# 9070 - Design de Comunicação
#
# 9085 - Enfermagem Veterinária
#
# 9119 - Engenharia Informática
#
# 9130 - Equincultura
#
# 9147 - Gestão
#
# 9238 - Serviço Social
#
# 9254 - Turismo
#
# 9500 - Enfermagem
#
# 9556 - Higiene Oral
#
# 9670 - Gestão de Publicidade e Marketing
#
# 9773 - Jornalismo e Comunicação
#
# 9853 - Ensino Básico
#
# 9991 - Gestão (presencial noturno).
#
# Os cursos com maiores números de estudantes:
#
#     - Enfermagem;
#
#     - Gestão;
#
#     - Serviço Social.

# %% [markdown]
# ## Separando as bases de dados para iniciar os estudos direcionados por status

# %%
df_evadidos = df[df['Target'] == "Dropout"]
df_matriculados = df[df['Target'] == "Enrolled"]
df_graduados = df[df['Target'] == "Graduate"]

# %%
set(df_evadidos['Target'])
# Out:
# {'Dropout'}

# %%
df_courses_evadidos = df_evadidos.groupby('Curso')['Curso'].count().sort_values(ascending=False)
df_courses_graduados = df_graduados.groupby('Curso')['Curso'].count().sort_values(ascending=False)

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
df_courses_evadidos.plot(kind='bar', color='orange', label= 'Evadidos')
plt.title('Evadidos')

plt.subplot(1, 2, 2)
df_courses_graduados.plot(kind='bar', color='orange', label= 'Graduados')
plt.title('Graduados')

# Ajustando o layout para evitar sobreposição
plt.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# Temos mais graduados em Enfermagem e mais evadidos em Gestão (presencial noturno) e Gestão.

# %% [markdown]
# ## Analisando os comportamentos das variáveis binárias

# %%
df_evadidos_MensalidadesEmDia = df_evadidos.groupby('MensalidadesEmDia')['MensalidadesEmDia'].count()
df_graduados_MensalidadesEmDia = df_graduados.groupby('MensalidadesEmDia')['MensalidadesEmDia'].count()

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
df_evadidos_MensalidadesEmDia.plot(kind='bar', color='orange', label= 'Evadidos')
plt.title('Evadidos')

plt.subplot(1, 2, 2)
df_graduados_MensalidadesEmDia.plot(kind='bar', color='orange', label= 'Graduados')
plt.title('Graduados')

plt.tight_layout()

plt.show()

# %%
df_evadidos_Devedor = df_evadidos.groupby('Devedor')['Devedor'].count()
df_graduados_Devedor = df_graduados.groupby('Devedor')['Devedor'].count()

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
df_evadidos_Devedor.plot(kind='bar', color='orange', label= 'Evadidos')
plt.title('Evadidos')

plt.subplot(1, 2, 2)
df_graduados_Devedor.plot(kind='bar', color='orange', label= 'Graduados')
plt.title('Graduados')

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 5))
df_Genero = df.groupby('Genero')['Genero'].count()
df_Genero.plot(kind='bar', color='orange')

# Adicionar rótulos nas barras
for i, df_Genero in enumerate(df_Genero):
    plt.text(i, df_Genero + 1, str(df_Genero), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de pessoas por gênero')
plt.xlabel('Status')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Gênero: 1 – masculino 0 – feminino

# %%
df_evadidos_Bolsista = df_evadidos.groupby('Bolsista')['Bolsista'].count()
df_graduados_Bolsista = df_graduados.groupby('Bolsista')['Bolsista'].count()

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
df_evadidos_Bolsista.plot(kind='bar', color='orange', label= 'Evadidos')
plt.title('Evadidos')

plt.subplot(1, 2, 2)
df_graduados_Bolsista.plot(kind='bar', color='orange', label= 'Graduados')
plt.title('Graduados')

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 5))
df_NecessidadesEspeciais = df.groupby('NecessidadesEspeciais')['NecessidadesEspeciais'].count()
df_NecessidadesEspeciais.plot(kind='bar', color='orange')

# Adicionar rótulos nas barras
for i, df_NecessidadesEspeciais in enumerate(df_NecessidadesEspeciais):
    plt.text(i, df_NecessidadesEspeciais + 1, str(df_NecessidadesEspeciais), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de pessoas por necessidades especiais')
plt.xlabel('Status')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Live 08-08

# %% [markdown]
# ## Analisando as variáveis categóricas

# %%
plt.figure(figsize=(8, 5))
df_EstadoCivil = df.groupby('EstadoCivil')['EstadoCivil'].count()
df_EstadoCivil.plot(kind='bar', color='orange')

# Adicionar rótulos nas barras
for i, df_EstadoCivil in enumerate(df_EstadoCivil):
    plt.text(i, df_EstadoCivil + 1, str(df_EstadoCivil), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de pessoas por status civil')
plt.xlabel('Status')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Estado civil: 1 – solteiro 2 – casado 3 – viúvo 4 – divorciado 5 – união de fato 6 – separado judicialmente

# %%
plt.figure(figsize=(8, 5))
df_Nacionalidade = df.groupby('Nacionalidade')['Nacionalidade'].count()
df_Nacionalidade.plot(kind='bar', color='orange')

# Adicionar rótulos nas barras
for i, df_Nacionalidade in enumerate(df_Nacionalidade):
    plt.text(i, df_Nacionalidade + 1, str(df_Nacionalidade), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de pessoas por Nacionalidade')
plt.xlabel('Status')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Nacionalidade: 1 - Português; 2 - Alemão; 6 - Espanhol; 11 - Italiano; 13 - holandês; 14 - Inglês; 17 - lituano; 21 - angolano; 22 - cabo-verdiana; 24 - Guineense; 25 - moçambicano; 26 - Santomense; 32 - turco; 41 - Brasileiro; 62 - romeno; 100 - Moldávia (República da); 101 - Mexicana; 103 - Ucraniano; 105 - russo; 108 - cubano; 109 - Colombiano

# %%
plt.figure(figsize=(8, 5))
df_QualificacaoAnterior = df.groupby('QualificacaoAnterior')['QualificacaoAnterior'].count()
df_QualificacaoAnterior.plot(kind='bar', color='orange')

# Adicionar rótulos nas barras
for i, df_QualificacaoAnterior in enumerate(df_QualificacaoAnterior):
    plt.text(i, df_QualificacaoAnterior + 1, str(df_QualificacaoAnterior), ha='center', va='bottom')

# Configurar título e rótulos dos eixos
plt.title('Total de pessoas por qualificação anterior')
plt.xlabel('Status')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Qualificação anterior: 1 - Ensino secundário 2 - Ensino superior - licenciatura 3 - Ensino superior - licenciatura 4 - Ensino superior - mestrado 5 - Ensino superior - doutoramento 6 - Frequência do ensino superior 9 - 12.º ano de escolaridade - não concluído 10 - 11.º ano de escolaridade - não concluído 12 - Outro - 11º ano de escolaridade 14 - 10º ano de escolaridade 15 - 10º ano de escolaridade - não concluído 19 - Ensino básico 3º ciclo (9º/10º/11º ano) ou equiv. 38 - Ensino básico 2º ciclo (6º/7º/8º ano) ou equiv. 39 - Curso de especialização tecnológica 40 - Ensino superior - licenciatura (1º ciclo) 42 - Curso técnico superior profissional 43 - Ensino superior - mestrado (2º ciclo)

# %% [markdown]
# ## Analisando fatores econômicos

# %%
import seaborn as sb

# %%
evadidos_TaxaDesemprego = df_evadidos['TaxaDesemprego']
graduados_TaxaDesemprego = df_graduados['TaxaDesemprego']


fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos_TaxaDesemprego, bins=5, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('Taxa de desemprego')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados_TaxaDesemprego, bins=5, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('Taxa de desemprego')
axes[1].set_ylabel('Frequência')


fig.tight_layout()
plt.show()

# %%
evadidos_PIB = df_evadidos['PIB']
graduados_PIB = df_graduados['PIB']


fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos_PIB, bins=5, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('PIB')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados_PIB, bins=5, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('PIB')
axes[1].set_ylabel('Frequência')


fig.tight_layout()
plt.show()

# %%
evadidos_TaxaInflacao = df_evadidos['TaxaInflacao']
graduados_TaxaInflacao = df_graduados['TaxaInflacao']


fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos_TaxaInflacao, bins=5, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('Taxa inflação')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados_TaxaInflacao, bins=5, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('Taxa inflação')
axes[1].set_ylabel('Frequência')


fig.tight_layout()
plt.show()

# %% [markdown]
# ## Analisando o desempenho acadêmico

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreCreditado']
graduados = df_graduados['UnidadesCurriculares1SemestreCreditado']

#Configurando para criar dois gráficos um do lado do outro.
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos, bins=20, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('UnidadesCurriculares1SemestreCreditado')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados, bins=20, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('UnidadesCurriculares1SemestreCreditado')
axes[1].set_ylabel('Frequência')

#Ajustando o espaçamento entre os gráficos e mostrando em nossa tela
fig.tight_layout()
plt.show()

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreInscrito']
graduados = df_graduados['UnidadesCurriculares1SemestreInscrito']

#Configurando para criar dois gráficos um do lado do outro.
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos, bins=20, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('UnidadesCurriculares1SemestreInscrito')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados, bins=20, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('UnidadesCurriculares1SemestreInscrito')
axes[1].set_ylabel('Frequência')

#Ajustando o espaçamento entre os gráficos e mostrando em nossa tela
fig.tight_layout()
plt.show()

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreAvaliacoes']
graduados = df_graduados['UnidadesCurriculares1SemestreAvaliacoes']

#Configurando para criar dois gráficos um do lado do outro.
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos, bins=20, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('UnidadesCurriculares1SemestreAvaliacoes')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados, bins=20, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('UnidadesCurriculares1SemestreAvaliacoes')
axes[1].set_ylabel('Frequência')

#Ajustando o espaçamento entre os gráficos e mostrando em nossa tela
fig.tight_layout()
plt.show()

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreAprovado']
graduados = df_graduados['UnidadesCurriculares1SemestreAprovado']

#Configurando para criar dois gráficos um do lado do outro.
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos, bins=20, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('UnidadesCurriculares1SemestreAprovado')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados, bins=20, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('UnidadesCurriculares1SemestreAprovado')
axes[1].set_ylabel('Frequência')

#Ajustando o espaçamento entre os gráficos e mostrando em nossa tela
fig.tight_layout()
plt.show()

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreGrau']
graduados = df_graduados['UnidadesCurriculares1SemestreGrau']

#Configurando para criar dois gráficos um do lado do outro.
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos, bins=20, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('UnidadesCurriculares1SemestreGrau')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados, bins=20, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('UnidadesCurriculares1SemestreGrau')
axes[1].set_ylabel('Frequência')

#Ajustando o espaçamento entre os gráficos e mostrando em nossa tela
fig.tight_layout()
plt.show()

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreSemAvaliacoes']
graduados = df_graduados['UnidadesCurriculares1SemestreSemAvaliacoes']

#Configurando para criar dois gráficos um do lado do outro.
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

#Criando o primeiro gráfico
sb.histplot(data=evadidos, bins=20, ax=axes[0])
axes[0].set_title('Evadidos')
axes[0].set_xlabel('UnidadesCurriculares1SemestreSemAvaliacoes')
axes[0].set_ylabel('Frequência')

#Criando o segundo gráfico
sb.histplot(data=graduados, bins=20, ax=axes[1])
axes[1].set_title('Graduados')
axes[1].set_xlabel('UnidadesCurriculares1SemestreSemAvaliacoes')
axes[1].set_ylabel('Frequência')

#Ajustando o espaçamento entre os gráficos e mostrando em nossa tela
fig.tight_layout()
plt.show()

# %% [markdown]
# Observamos que as variáveis acadêmicas que possuem grande diferença entre as distribuições dos grupos evadidos e formandos está entre as notas:
#
# * UnidadesCurricularesSemestreAvaliacoes
#
# * UnidadesCurricularesSemestreAprovado
#
# * UnidadesCurricularesSemestreGrau
#
# Vamos validar algumas hipóteses?

# %% [markdown]
# ## Testes de hipótese: saindo do achismo!

# %%
from scipy.stats import mannwhitneyu
from scipy.stats import shapiro
import scipy.stats as stats

# %% [markdown]
# O número de aprovações do 1 semestre para evadidos são menores do que para formandos?

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreAprovado']
graduados = df_graduados['UnidadesCurriculares1SemestreAprovado']

#Uma outra forma de visualizarmos a distruibuição da frequência dos valores é criando um gráfico de densidade.
plt.figure(figsize=(10, 5))

#Criando o gráfico de densidade usando ambos dataframes
sb.kdeplot(data=graduados, label='UnidadesCurriculares1SemestreAprovado em graduados', fill=True)
sb.kdeplot(data=evadidos, label='UnidadesCurriculares1SemestreAprovado em evadidos', fill=True)
plt.title('Distribuição de notas')
plt.xlabel('Quantidade de notas')
plt.ylabel('Densidade')
plt.legend()
plt.show()

# %%
stat, p = shapiro(graduados)
print("Estatística de teste: {:.4f}, valor p: {}".format(stat, p))

if p > 0.05:
  print("Não há evidência suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Estatística de teste: 0.7501, valor p: 0.0
# A hipótese de normalidade é rejeitada

# %%
stat, p = shapiro(evadidos)
print("Estatística de teste: {:.4f}, valor p: {}".format(stat, p))

if p > 0.05:
  print("Não há evidência suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Estatística de teste: 0.8238, valor p: 6.84395963638275e-37
# A hipótese de normalidade é rejeitada

# %%
stat, p = mannwhitneyu(evadidos.sample(len(evadidos)), graduados.sample(len(graduados)), alternative="less")

print("Estatísica de teste U: ", stat)
print("Valor p: ", p)

alpha = 0.05
if p < alpha:
  print("Diferença estatisticamente significante")
else:
  print("Não há dieferença estatisticamente significante")
# Out:
# Estatísica de teste U:  444728.0
# Valor p:  3.729804012571768e-302
# Diferença estatisticamente significante

# %% [markdown]
# O número de aprovações do 2 semestre para evadidos são menores do que para formandos?

# %%
evadidos = df_evadidos['UnidadesCurriculares2SemestreAprovado']
graduados = df_graduados['UnidadesCurriculares2SemestreAprovado']

#Uma outra forma de visualizarmos a distruibuição da frequência dos valores é criando um gráfico de densidade.
plt.figure(figsize=(10, 5))

#Criando o gráfico de densidade usando ambos dataframes
sb.kdeplot(data=graduados, label='UnidadesCurriculares2SemestreAprovado em graduados', fill=True)
sb.kdeplot(data=evadidos, label='UnidadesCurriculares2SemestreAprovado em evadidos', fill=True)
plt.title('Distribuição de notas')
plt.xlabel('Quantidade de notas')
plt.ylabel('Densidade')
plt.legend()
plt.show()

# %%
stat, p = shapiro(graduados)
print("Estatística de teste: {:.4f}, valor p: {}".format(stat, p))

if p > 0.05:
  print("Não há evidência suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Estatística de teste: 0.8402, valor p: 1.5218101322567513e-42
# A hipótese de normalidade é rejeitada

# %%
stat, p = shapiro(evadidos)
print("Estatística de teste: {:.4f}, valor p: {}".format(stat, p))

if p > 0.05:
  print("Não há evidência suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Estatística de teste: 0.7686, valor p: 9.116567549204395e-41
# A hipótese de normalidade é rejeitada

# %%
stat, p = mannwhitneyu(evadidos.sample(len(evadidos)), graduados.sample(len(graduados)), alternative="less")

print("Estatísica de teste U: ", stat)
print("Valor p: ", p)

alpha = 0.05
if p < alpha:
  print("Diferença estatisticamente significante")
else:
  print("Não há dieferença estatisticamente significante")
# Out:
# Estatísica de teste U:  339114.5
# Valor p:  0.0
# Diferença estatisticamente significante

# %% [markdown]
# As médias de notas no 1º semestre (entre 0 e 20) para evadidos são menores do que para formandos?

# %%
evadidos = df_evadidos['UnidadesCurriculares1SemestreGrau']
graduados = df_graduados['UnidadesCurriculares1SemestreGrau']

#Uma outra forma de visualizarmos a distruibuição da frequência dos valores é criando um gráfico de densidade.
plt.figure(figsize=(10, 5))

#Criando o gráfico de densidade usando ambos dataframes
sb.kdeplot(data=graduados, label='UnidadesCurriculares1SemestreGrau em graduados', fill=True)
sb.kdeplot(data=evadidos, label='UnidadesCurriculares1SemestreGrau em evadidos', fill=True)
plt.title('Distribuição de notas')
plt.xlabel('Quantidade de notas')
plt.ylabel('Densidade')
plt.legend()
plt.show()

# %%
stat, p = shapiro(graduados)
print("Estatística de teste: {:.4f}, valor p: {}".format(stat, p))

if p > 0.05:
  print("Não há evidência suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Estatística de teste: 0.7133, valor p: 0.0
# A hipótese de normalidade é rejeitada

# %%
stat, p = shapiro(evadidos)
print("Estatística de teste: {:.4f}, valor p: {}".format(stat, p))

if p > 0.05:
  print("Não há evidência suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Estatística de teste: 0.4737, valor p: 0.0
# A hipótese de normalidade é rejeitada

# %%
stat, p = mannwhitneyu(evadidos.sample(len(evadidos)), graduados.sample(len(graduados)), alternative="less")

print("Estatísica de teste U: ", stat)
print("Valor p: ", p)

alpha = 0.05
if p < alpha:
  print("Diferença estatisticamente significante")
else:
  print("Não há dieferença estatisticamente significante")
# Out:
# Estatísica de teste U:  591285.5
# Valor p:  1.1018601050805499e-222
# Diferença estatisticamente significante

# %% [markdown]
# ## Configurando a variável target

# %%
set(df['Target'])
# Out:
# {'Dropout', 'Enrolled', 'Graduate'}

# %%
#Utilizadno Label Enconder

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df.Target = le.fit_transform(df['Target'])

# %%
set(df['Target'])
# Out:
# {0, 1, 2}

# %%
df.groupby('Target')['Target'].count()
#0 = dropout
#1 = enrolled
#2 = graduate
# Out:
# Target
# 0    1421
# 1     794
# 2    2209
# Name: Target, dtype: int64

# %%
df_evadidos = df[df['Target'] == 0]
df_matriculados = df[df['Target'] == 1]
df_graduados = df[df['Target'] == 2]

# %%
df_concatenado = pd.concat([df_evadidos, df_graduados])

# %%
df_concatenado.head()
# Out:
#     EstadoCivil  Curso  QualificacaoAnterior  QualificacaoAnteriorGrau  \
# 0             1    171                     1                     122.0
# 2             1   9070                     1                     122.0
# 7             1   9254                     1                     119.0
# 9             1   9238                     1                     138.0
# 12            1   9853                     1                     133.0
#
#     Nacionalidade  NotaAdmissao  NecessidadesEspeciais  Devedor  \
# 0               1         127.3                      0        0
# 2               1         124.8                      0        0
# 7               1         113.1                      0        0
# 9               1         123.0                      0        1
# 12              1         130.2                      0        0
#
#     MensalidadesEmDia  Genero  ...  UnidadesCurriculares2SemestreCreditado  \
# 0                   1       1  ...                                       0
# 2                   0       1  ...                                       0
# 7                   0       1  ...                                       0
# 9                   0       0  ...                                       0
# 12                  1       0  ...                                       0
#
#     UnidadesCurriculares2SemestreInscrito  \
# 0                                       0
# 2                                       6
# 7                                       5
# 9                                       6
# 12                                      6
#
#     UnidadesCurriculares2SemestreAvaliacoes  \
# 0                                         0
# 2                                         0
# 7                                         5
# 9                                        14
# 12                                        0
#
#     UnidadesCurriculares2SemestreAprovado  UnidadesCurriculares2SemestreGrau  \
# 0                                       0                                0.0
# 2                                       0                                0.0
# 7                                       0                                0.0
# 9                                       2                               13.5
# 12                                      0                                0.0
#
#     UnidadesCurriculares2SemestreSemAvaliacoes  TaxaDesemprego  TaxaInflacao  \
# 0                                            0            10.8           1.4
# 2                                            0            10.8           1.4
# 7                                            0            15.5           2.8
# 9                                            0             8.9           1.4
# 12                                           0            12.7           3.7
#
#      PIB  Target
# 0   1.74       0
# 2   1.74       0
# 7  -4.06       0
# 9   3.51       0
# 12 -1.70       0
#
# [5 rows x 28 columns]

# %%
set(df_concatenado['Target'])
# Out:
# {0, 2}

# %%
df_concatenado.Target = le.fit_transform(df_concatenado['Target'])

# %%
set(df_concatenado['Target'])
# Out:
# {0, 1}

# %%
df_concatenado_streamlit = df_concatenado[['Devedor', 'TaxaDesemprego', 'MensalidadesEmDia', 'Bolsista', 'UnidadesCurriculares1SemestreAprovado', 'UnidadesCurriculares1SemestreAvaliacoes', 'UnidadesCurriculares2SemestreAvaliacoes', 'UnidadesCurriculares1SemestreGrau', 'UnidadesCurriculares2SemestreGrau']]
df_concatenado_streamlit.to_csv('df_concatenado.csv', index=False)

# %% [markdown]
# # Validando o equilíbrio das targets

# %%
def check_class_balance(y):
    class_counts = pd.Series(y).value_counts()
    total_samples = len(y)

    print("Número de amostras por classe:")
    print(class_counts)

    print("\nProporção de amostras por classe:")
    print(class_counts / total_samples)

# %%
check_class_balance(df_concatenado['Target'])
# Out:
# Número de amostras por classe:
# Target
# 1    2209
# 0    1421
# Name: count, dtype: int64
#
# Proporção de amostras por classe:
# Target
# 1    0.60854
# 0    0.39146
# Name: count, dtype: float64

# %% [markdown]
# ## Analisando as correlações

# %%
correlation_matrix = df_concatenado.corr().round(2)

fig, ax = plt.subplots(figsize=(20,20))
sb.heatmap(data=correlation_matrix, annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## Separando as bases em treino e teste

# %%
from sklearn.model_selection import train_test_split

# %%
#x = df_concatenado.drop('Target', axis=1)
x = df_concatenado[['Devedor', 'TaxaDesemprego', 'MensalidadesEmDia', 'Bolsista', 'UnidadesCurriculares1SemestreAprovado', 'UnidadesCurriculares1SemestreAvaliacoes', 'UnidadesCurriculares2SemestreAvaliacoes', 'UnidadesCurriculares1SemestreGrau', 'UnidadesCurriculares2SemestreGrau']]
y = df_concatenado['Target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=7)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2904, 9) (726, 9)

# %% [markdown]
# ## Pré-processamento
# Ao aplicar o MinMaxScaler, todos os valores dos dados serão transformados para o intervalo entre 0 e 1, onde o valor mínimo será 0 e o valor máximo será 1. Essa técnica é especialmente útil quando os algoritmos de aprendizado de máquina são sensíveis à escala dos dados.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

scaler.fit(x_train)

x_train_escalonado = scaler.transform(x_train)
x_test_escalonado = scaler.transform(x_test)

# %%
x_train_escalonado
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 1.00000000e+00, ...,
#         2.59259259e-01, 7.50000000e-16, 7.17948718e-01],
#        [0.00000000e+00, 1.51162791e-01, 1.00000000e+00, ...,
#         2.59259259e-01, 7.82967033e-01, 6.35384615e-16],
#        [0.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         2.59259259e-01, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 7.32558140e-01, 1.00000000e+00, ...,
#         3.33333333e-01, 8.56730769e-16, 8.40598291e-02],
#        [0.00000000e+00, 4.06976744e-01, 1.00000000e+00, ...,
#         2.59259259e-01, 6.99519231e-13, 7.30769231e-01],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, ...,
#         5.18518519e-01, 7.30769231e-01, 0.00000000e+00]])

# %% [markdown]
# ## Próximos passos:
#
# * Validar algoritmos de classificação na base de dados.
# * Validar escopo da target e performance do modelo.
# * Testar o modelo com novos dados! 😃

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/marcelocardoso/Documents/.venv/lib/python3.10/site-packages (1.7.6)
# Requirement already satisfied: numpy in /Users/marcelocardoso/Documents/.venv/lib/python3.10/site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in /Users/marcelocardoso/Documents/.venv/lib/python3.10/site-packages (from xgboost) (1.10.1)

# %%
def AplicaValidacaoCruzada(x_axis, y_axis):
    from sklearn.neighbors import KNeighborsClassifier      # k-vizinhos mais próximos (KNN)
    from sklearn.linear_model import LogisticRegression     # Regressão Logística
    from sklearn.tree import DecisionTreeClassifier         # Decision tree
    from sklearn.ensemble import RandomForestClassifier     # RandomForest
    from sklearn.svm import SVC                             # Maquina de Vetor Suporte SVM
    from sklearn.ensemble import GradientBoostingClassifier # XGBoost (Extreme Gradient Boosting)


    # Cross-Validation models.
    from sklearn.model_selection import cross_val_score
    from sklearn.model_selection import KFold

    # Configuração de KFold.
    kfold  = KFold(n_splits=30, shuffle=True)

    # Axis
    x = x_axis
    y = y_axis

    # Criando os modelos
    # KNN
    knn = KNeighborsClassifier(n_neighbors=3, metric= 'euclidean', weights='distance')
    knn.fit(x, y)

    # Regressão Logística
    lr = LogisticRegression()
    lr.fit(x, y)

    # SVM
    svm = SVC()
    svm.fit(x, y)

    # RandomForest
    rf = RandomForestClassifier()
    rf.fit(x, y)

    # Decision Tree
    dt = DecisionTreeClassifier()
    dt.fit(x, y)

    # Extreme Gradient Boosting
    xgb = GradientBoostingClassifier()
    xgb.fit(x,y)


    # Applyes KFold to models.
    knn_result = cross_val_score(knn, x, y, cv = kfold)
    lr_result = cross_val_score(lr, x, y, cv = kfold)
    svm_result = cross_val_score(svm, x, y, cv = kfold)
    rf_result = cross_val_score(rf, x, y, cv = kfold)
    dt_result = cross_val_score(dt, x, y, cv = kfold)
    xgb_result = cross_val_score(xgb, x, y, cv = kfold)

  # Creates a dictionary to store Linear Models.
    dic_models = {
        "KNN": knn_result.mean(),
        "LR": lr_result.mean(),
        "SVM": svm_result.mean(),
        "RF": rf_result.mean(),
        "DT": dt_result.mean(),
        "XGB": xgb_result.mean()
                }

    # Select the best model.
    melhorModelo = max(dic_models, key=dic_models.get)

    print("KNN (R^2): {0}\nRegressão Logística (R^2): {1}\nSVM (R^2): {2}\nRandom Forest (R^2): {3}\nÁrvore de Decisão (R^2): {4}\nXGBoost (R^2): {5}".format(knn_result.mean(),lr_result.mean(), svm_result.mean(), rf_result.mean(), dt_result.mean(), xgb_result.mean()))
    print("O melhor modelo é : {0} com o valor: {1}".format(melhorModelo, dic_models[melhorModelo]))

# %%
import warnings
# Suprimir todos os avisos
warnings.filterwarnings("ignore")

# %%
AplicaValidacaoCruzada(x_train, y_train)
# Out:
# KNN (R^2): 0.8088810137457046
# Regressão Logística (R^2): 0.3914948453608248
# SVM (R^2): 0.6838845933562427
# Random Forest (R^2): 0.8863581042382589
# Árvore de Decisão (R^2): 0.8350945017182131
# XGBoost (R^2): 0.8870310710194732
# O melhor modelo é : XGB com o valor: 0.8870310710194732

# %%
AplicaValidacaoCruzada(x_train_escalonado, y_train)
# Out:
# KNN (R^2): 0.8460946449026346
# Regressão Logística (R^2): 0.873263888888889
# SVM (R^2): 0.8663588201603665
# Random Forest (R^2): 0.8715528350515463
# Árvore de Decisão (R^2): 0.8154138029782358
# XGBoost (R^2): 0.8767182130584191
# O melhor modelo é : XGB com o valor: 0.8767182130584191

# %% [markdown]
# ## Será que podemos confiar no modelo?
#
# ## GradientBoostingClassifier

# %%
def melhores_hiperparamentros_xgb(x_train_scaled, y_train):
  from sklearn.model_selection import GridSearchCV
  from sklearn.metrics import accuracy_score, make_scorer
  from sklearn.ensemble import GradientBoostingClassifier
  import numpy as np

    # Parâmetros testados
  param_grid = {
            'learning_rate': [0.01,0.02,0.03],
            'n_estimators' : [100,500,1000],
            'max_depth'    : [4,6,8]
              }

    # Métrica de desempenho = melhor acurácia
  gs_metric = make_scorer(accuracy_score, greater_is_better=True)

  grid = GridSearchCV(GradientBoostingClassifier(),
                      param_grid=param_grid,
                      scoring=gs_metric,
                      cv=3, n_jobs=5, verbose=3)  # cv = gerador de validação cruzada / n_jobs = determina a quantidade de jobs processados

  grid.fit(x_train_scaled, y_train)  # Selecionando os melhores hiperparâmetros com base nos dados de treino
  xgb_params = grid.best_params_
  return xgb_params

# %%
melhores_hiperparamentros_xgb(x_train_escalonado, y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 3/3] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.864 total time=   0.2s
# [CV 1/3] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.870 total time=   0.2s
# [CV 2/3] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=0.861 total time=   0.2s
# [CV 2/3] END learning_rate=0.01, max_depth=4, n_estimators=500;, score=0.875 total time=   1.0s
# [CV 1/3] END learning_rate=0.01, max_depth=4, n_estimators=500;, score=0.877 total time=   1.0s
# [CV 3/3] END learning_rate=0.01, max_depth=4, n_estimators=500;, score=0.871 total time=   0.9s
# [CV 1/3] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.878 total time=   0.3s
# [CV 2/3] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.864 total time=   0.3s
# [CV 3/3] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=0.867 total time=   0.3s
# [CV 2/3] END learning_rate=0.01, max_depth=4, n_estimators=1000;, score=0.877 total time=   1.9s
# [CV 1/3] END learning_rate=0.01, max_depth=4, n_estimators=1000;, score=0.875 total time=   2.0s
# [CV 1/3] END learning_rate=0.01, max_depth=6, n_estimators=500;, score=0.882 total time=   1.6s
# [CV 3/3] END learning_rate=0.01, max_depth=4, n_estimators=1000;, score=0.868 total time=   2.0s
# [CV 2/3] END learning_rate=0.01, max_depth=6, n_estimators=500;, score=0.870 total time=   1.6s
# [CV 1/3] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=0.876 total time=   0.4s
# [CV 3/3] END learning_rate=0.01, max_depth=6, n_estimators=500;, score=0.868 total time=   1.6s
# [CV 2/3] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=0.851 total time=   0.4s
# [CV 3/3] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=0.846 total time=   0.5s
# [CV 1/3] END learning_rate=0.01, max_depth=6, n_estimators=1000;, score=0.874 total time=   3.2s
# [CV 2/3] END learning_rate=0.01, max_depth=6, n_estimators=1000;, score=0.868 total time=   3.0s
# [CV 3/3] END learning_rate=0.01, max_depth=6, n_estimators=1000;, score=0.864 total time=   3.1s
# [CV 2/3] END learning_rate=0.01, max_depth=8, n_estimators=500;, score=0.869 total time=   2.3s
# [CV 1/3] END learning_rate=0.01, max_depth=8, n_estimators=500;, score=0.876 total time=   2.5s
# [CV 1/3] END learning_rate=0.02, max_depth=4, n_estimators=100;, score=0.873 total time=   0.2s
# [CV 2/3] END learning_rate=0.02, max_depth=4, n_estimators=100;, score=0.873 total time=   0.2s
# [CV 3/3] END learning_rate=0.02, max_depth=4, n_estimators=100;, score=0.871 total time=   0.2s
# [CV 3/3] END learning_rate=0.01, max_depth=8, n_estimators=500;, score=0.865 total time=   2.4s
# [CV 1/3] END learning_rate=0.02, max_depth=4, n_estimators=500;, score=0.874 total time=   1.0s
# [CV 2/3] END learning_rate=0.02, max_depth=4, n_estimators=500;, score=0.879 total time=   0.9s
# [CV 3/3] END learning_rate=0.02, max_depth=4, n_estimators=500;, score=0.866 total time=   1.0s
# [CV 1/3] END learning_rate=0.02, max_depth=4, n_estimators=1000;, score=0.870 total time=   2.1s
# [CV 1/3] END learning_rate=0.01, max_depth=8, n_estimators=1000;, score=0.867 total time=   4.8s
# [CV 2/3] END learning_rate=0.01, max_depth=8, n_estimators=1000;, score=0.867 total time=   4.8s
# [CV 2/3] END learning_rate=0.02, max_depth=4, n_estimators=1000;, score=0.879 total time=   2.0s
# [CV 1/3] END learning_rate=0.02, max_depth=6, n_estimators=100;, score=0.877 total time=   0.3s
# [CV 2/3] END learning_rate=0.02, max_depth=6, n_estimators=100;, score=0.866 total time=   0.3s
# [CV 3/3] END learning_rate=0.02, max_depth=6, n_estimators=100;, score=0.868 total time=   0.3s
# [CV 3/3] END learning_rate=0.01, max_depth=8, n_estimators=1000;, score=0.860 total time=   5.0s
# [CV 1/3] END learning_rate=0.02, max_depth=6, n_estimators=500;, score=0.871 total time=   1.6s
# [CV 2/3] END learning_rate=0.02, max_depth=6, n_estimators=500;, score=0.869 total time=   1.6s
# [CV 3/3] END learning_rate=0.02, max_depth=4, n_estimators=1000;, score=0.863 total time=   2.0s
# [CV 3/3] END learning_rate=0.02, max_depth=6, n_estimators=500;, score=0.865 total time=   1.6s
# [CV 1/3] END learning_rate=0.02, max_depth=8, n_estimators=100;, score=0.876 total time=   0.4s
# [CV 2/3] END learning_rate=0.02, max_depth=8, n_estimators=100;, score=0.865 total time=   0.4s
# [CV 3/3] END learning_rate=0.02, max_depth=8, n_estimators=100;, score=0.860 total time=   0.5s
# [CV 1/3] END learning_rate=0.02, max_depth=6, n_estimators=1000;, score=0.862 total time=   3.2s
# [CV 1/3] END learning_rate=0.02, max_depth=8, n_estimators=500;, score=0.861 total time=   2.4s
# [CV 2/3] END learning_rate=0.02, max_depth=6, n_estimators=1000;, score=0.861 total time=   3.1s
# [CV 3/3] END learning_rate=0.02, max_depth=6, n_estimators=1000;, score=0.861 total time=   3.1s
# [CV 2/3] END learning_rate=0.02, max_depth=8, n_estimators=500;, score=0.875 total time=   2.4s
# [CV 1/3] END learning_rate=0.03, max_depth=4, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 2/3] END learning_rate=0.03, max_depth=4, n_estimators=100;, score=0.870 total time=   0.2s
# [CV 3/3] END learning_rate=0.03, max_depth=4, n_estimators=100;, score=0.874 total time=   0.2s
# [CV 3/3] END learning_rate=0.02, max_depth=8, n_estimators=500;, score=0.861 total time=   2.3s
# [CV 1/3] END learning_rate=0.03, max_depth=4, n_estimators=500;, score=0.874 total time=   1.1s
# [CV 2/3] END learning_rate=0.03, max_depth=4, n_estimators=500;, score=0.879 total time=   1.1s
# [CV 3/3] END learning_rate=0.03, max_depth=4, n_estimators=500;, score=0.863 total time=   1.0s
# [CV 1/3] END learning_rate=0.03, max_depth=4, n_estimators=1000;, score=0.873 total time=   2.1s
# [CV 1/3] END learning_rate=0.02, max_depth=8, n_estimators=1000;, score=0.856 total time=   5.1s
# [CV 2/3] END learning_rate=0.03, max_depth=4, n_estimators=1000;, score=0.871 total time=   2.0s
# [CV 3/3] END learning_rate=0.02, max_depth=8, n_estimators=1000;, score=0.860 total time=   5.0s
# [CV 2/3] END learning_rate=0.02, max_depth=8, n_estimators=1000;, score=0.868 total time=   5.1s
# [CV 1/3] END learning_rate=0.03, max_depth=6, n_estimators=100;, score=0.881 total time=   0.3s
# [CV 2/3] END learning_rate=0.03, max_depth=6, n_estimators=100;, score=0.872 total time=   0.3s
# [CV 3/3] END learning_rate=0.03, max_depth=6, n_estimators=100;, score=0.866 total time=   0.3s
# [CV 3/3] END learning_rate=0.03, max_depth=4, n_estimators=1000;, score=0.857 total time=   2.0s
# [CV 1/3] END learning_rate=0.03, max_depth=6, n_estimators=500;, score=0.867 total time=   1.5s
# [CV 2/3] END learning_rate=0.03, max_depth=6, n_estimators=500;, score=0.868 total time=   1.5s
# [CV 3/3] END learning_rate=0.03, max_depth=6, n_estimators=500;, score=0.861 total time=   1.5s
# [CV 1/3] END learning_rate=0.03, max_depth=8, n_estimators=100;, score=0.878 total time=   0.5s
# [CV 2/3] END learning_rate=0.03, max_depth=8, n_estimators=100;, score=0.871 total time=   0.5s
# [CV 3/3] END learning_rate=0.03, max_depth=8, n_estimators=100;, score=0.861 total time=   0.5s
# [CV 1/3] END learning_rate=0.03, max_depth=6, n_estimators=1000;, score=0.861 total time=   3.2s
# [CV 2/3] END learning_rate=0.03, max_depth=6, n_estimators=1000;, score=0.862 total time=   3.1s
# [CV 1/3] END learning_rate=0.03, max_depth=8, n_estimators=500;, score=0.858 total time=   2.4s
# [CV 3/3] END learning_rate=0.03, max_depth=6, n_estimators=1000;, score=0.856 total time=   3.3s
# [CV 2/3] END learning_rate=0.03, max_depth=8, n_estimators=500;, score=0.864 total time=   2.4s
# [CV 3/3] END learning_rate=0.03, max_depth=8, n_estimators=500;, score=0.860 total time=   2.3s
# [CV 1/3] END learning_rate=0.03, max_depth=8, n_estimators=1000;, score=0.854 total time=   4.4s
# [CV 2/3] END learning_rate=0.03, max_depth=8, n_estimators=1000;, score=0.869 total time=   4.3s
# [CV 3/3] END learning_rate=0.03, max_depth=8, n_estimators=1000;, score=0.857 total time=   4.3s
# {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 500}

# %% [markdown]
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 500}

# %%
from sklearn.ensemble import GradientBoostingClassifier
xgb = GradientBoostingClassifier()
xgb.fit(x_train_escalonado, y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# # Próxima Live 22/08

# %%
def evaluate_model(model, X_val, y_val):
    from sklearn.metrics import roc_curve, roc_auc_score, classification_report

    # Fazer previsões de probabilidades
    y_pred_probs = model.predict_proba(X_val)[:, 1]

    # Calcular a curva ROC
    fpr, tpr, thresholds = roc_curve(y_val, y_pred_probs)

    # Calcular a AUC (área sob a curva ROC)
    auc = roc_auc_score(y_val, y_pred_probs)

    # Plotar a curva ROC
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Taxa de Falso Positivo')
    plt.ylabel('Taxa de Verdadeiro Positivo')
    plt.title('Curva ROC')
    plt.legend(loc='lower right')
    plt.show()

    # Converter probabilidades em classes preditas (0 ou 1)
    y_pred = (y_pred_probs > 0.5).astype(int)

    # Gerar o classification report
    report = classification_report(y_val, y_pred)
    print("Classification Report:")
    print(report)

# %%
evaluate_model(xgb, x_train_escalonado, y_train)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      1137
#            1       0.89      0.94      0.91      1767
#
#     accuracy                           0.89      2904
#    macro avg       0.89      0.88      0.89      2904
# weighted avg       0.89      0.89      0.89      2904

# %%
# Validando com ajuste dos hiperparametros

from sklearn.ensemble import GradientBoostingClassifier

xgb = GradientBoostingClassifier(learning_rate=0.01, max_depth=4, n_estimators=500)
xgb.fit(x_train_escalonado, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=4, n_estimators=500)

# %%
evaluate_model(xgb, x_train_escalonado, y_train)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86      1137
#            1       0.89      0.95      0.92      1767
#
#     accuracy                           0.90      2904
#    macro avg       0.90      0.88      0.89      2904
# weighted avg       0.90      0.90      0.90      2904

# %%
import pickle

modelo = xgb

# Salvar o modelo em um arquivo
with open('modelo_treinado.pkl', 'wb') as arquivo:
    pickle.dump(modelo, arquivo)

# %%
import joblib
modelo_xg = joblib.dump(modelo, 'modelo_treinado.joblib')

# %% [markdown]
# # Criando uma pipeline para o modelo

# %% [markdown]
# Para preparar as nossas classes da pipeline vamos precisar importar as classes BaseEstimator e o TransformerMixin . O BaseEstimator fornece os métodos get_params e set_params que todos os estimadores Scikit-learn exigem. Já o TransformerMixin permite que os dados sejam ajustados e transformados.

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline

# %%
class MinMax(BaseEstimator,TransformerMixin):

    def __init__(self,min_max_scaler  = ['TaxaDesemprego', 'UnidadesCurriculares1SemestreAprovado', 'UnidadesCurriculares1SemestreAvaliacoes', 'UnidadesCurriculares2SemestreAvaliacoes', 'UnidadesCurriculares1SemestreGrau', 'UnidadesCurriculares2SemestreGrau']):
        self.min_max_scaler = min_max_scaler

    def fit(self,df):
        return self

    def transform(self,df):
        min_max_enc = MinMaxScaler()
        df[self.min_max_scaler] = min_max_enc.fit_transform(df[self.min_max_scaler])
        return df

# %%
def pipeline(df):

    pipeline = Pipeline([
        ('min_max_scaler', MinMax())
    ])
    df_pipeline = pipeline.fit_transform(df)
    return df_pipeline

# %% [markdown]
# # Testando o modelo

# %%
df_teste = pd.read_excel('df_dados_teste.xlsx')

# %%
df_teste.head()
# Out:
#    Devedor  TaxaDesemprego  MensalidadesEmDia  Bolsista  \
# 0        1            10.8                  0         0
# 1        0             1.8                  1         1
#
#    UnidadesCurriculares1SemestreAprovado  \
# 0                                      1
# 1                                      7
#
#    UnidadesCurriculares1SemestreAvaliacoes  \
# 0                                        1
# 1                                        8
#
#    UnidadesCurriculares2SemestreAvaliacoes  UnidadesCurriculares1SemestreGrau  \
# 0                                        2                                  3
# 1                                        6                                 18
#
#    UnidadesCurriculares2SemestreGrau
# 0                                  4
# 1                                 20

# %%
new_predictions = xgb.predict(df_teste)

# Predições

#base de dados a ser processada pela pipeline
data = pd.read_excel('df_dados_teste.xlsx')

#base de dados original
data_original = pd.read_excel('df_dados_teste.xlsx')

# pipeline
data_normalized = pipeline(data)

# aplicando o modelo
model = joblib.load('modelo_treinado.joblib')

# predições
final_pred = model.predict(data_normalized)
data_original['Chance de evadir'] = final_pred

# Imprimir as previsões
print("Previsões para os novos dados:")
data_original.head()
# Out:
# Previsões para os novos dados:
#    Devedor  TaxaDesemprego  MensalidadesEmDia  Bolsista  \
# 0        1            10.8                  0         0
# 1        0             1.8                  1         1
#
#    UnidadesCurriculares1SemestreAprovado  \
# 0                                      1
# 1                                      7
#
#    UnidadesCurriculares1SemestreAvaliacoes  \
# 0                                        1
# 1                                        8
#
#    UnidadesCurriculares2SemestreAvaliacoes  UnidadesCurriculares1SemestreGrau  \
# 0                                        2                                  3
# 1                                        6                                 18
#
#    UnidadesCurriculares2SemestreGrau  Chance de evadir
# 0                                  4                 0
# 1                                 20                 1
