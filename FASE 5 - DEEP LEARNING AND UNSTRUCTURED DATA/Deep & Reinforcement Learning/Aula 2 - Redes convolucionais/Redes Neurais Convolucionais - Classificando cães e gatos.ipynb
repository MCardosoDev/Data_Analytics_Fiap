# %% [markdown]
# # Classificando cães 🐕 e gatos 🐈
#
#
#
#
#
#
# Você já imaginou criar uma rede neural para classificar imagens? As redes neurais convolucionais (CNNs) são amplamente utilizadas em uma variedade de aplicações de visão computacional e processamento de imagens devido à sua capacidade de aprender representações hierárquicas de dados.
#
# Na aula de hoje vamos criar uma rede neural para classificar cães e gatos. Sabemos que para os olhos humanos é fácil a identificação dos animais por meio de algumas diferenças entre ambos, tal como gatos possuem os olhos mais puxadinhos, orelhinhas mais pontudas e entre outras características. Mas também sabemos que temos cães que podem ter características semelhantes ao gato, tal como a orelhinha pontuda, cauda longa, e entre outras características. Será que a rede neural consegue distinguir os animais? Vamos codar e descobrir juntos!!
# ![caoegatinho.PNG](data:image/png;base64,...)
# # Sobre a base de dados
# Essa base de dados está disponível no Kaggle, lá é possível encontrar diversas bases para trabalhar com dados de visão computacional! Para nossa aula de hoje, selecionei essa base de gatinhos e cachorrinhos fofos!
#
# Link: https://www.kaggle.com/datasets/moazeldsokyx/dogs-vs-cats

# %% [markdown]
# ## Importando as bibliotecas que vamos utilizar na aula de hoje:

# %%
# Bibliotecas essenciais
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import cv2

# Para Deep Learning
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout, Conv2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers.legacy import Adam

# Para validação do modelo
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# from google.colab import drive
# drive.mount('/content/drive')

import os
pasta_imagens = Path("cat_dog_images")

# %% [markdown]
# Depois de importar as bibliotecas necessárias para realizar nosso projeto, vamos utilizar o glob para listar as imagens que possuem o padrão ".jpg" (que no caso são as imagens de cachorrinhos e gatinhos que estão aqui na pasta do drive).

# %%
# Listando todas as imagens do diretório
filepaths = list(pasta_imagens.glob(r'**/*.jpg'))
filepaths
# Out:
# [PosixPath('cat_dog_images/gatinho/cat.6.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.588.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.239.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.577.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.211.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.205.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12424.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12342.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12395.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.359.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12381.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.403.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.365.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.371.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.417.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.198.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.30.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.24.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.167.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.601.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.18.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.173.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.614.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.172.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.19.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.166.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.600.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.31.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.199.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.416.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.402.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.364.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12380.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12394.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.358.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12425.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12343.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12357.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12431.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.562.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.576.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.210.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.238.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.5.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.548.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.560.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.206.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.212.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.574.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12341.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12427.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12355.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12369.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.428.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12382.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12396.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.414.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.400.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.33.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.158.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.170.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.602.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.164.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.603.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.165.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.171.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.159.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.32.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.26.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.367.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.415.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12397.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12383.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.429.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.398.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12432.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12354.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12340.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12426.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.213.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.575.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.561.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.549.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.4.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.0.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.565.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.571.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.217.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.559.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12378.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.388.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12422.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12350.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.377.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.411.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.405.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.363.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12387.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12393.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.439.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.613.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.161.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.607.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.22.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.149.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.36.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.23.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.160.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.606.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.612.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.438.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12392.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.362.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.376.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12437.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.389.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.558.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.570.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.216.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.1.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.3.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.599.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.214.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.572.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.566.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.200.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.228.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12409.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12435.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12353.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12347.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12421.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.360.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.406.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.412.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.374.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12384.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.189.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.604.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.176.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.610.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.21.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.20.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.34.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.177.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.611.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.163.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.188.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.349.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12391.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.413.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.375.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.361.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.407.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12346.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12420.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12434.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12352.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12408.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.229.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.567.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.201.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.215.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.573.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.598.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12241.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.299.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.528.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12282.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12296.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.272.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.514.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.500.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.266.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12453.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12335.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12321.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12447.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12309.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12490.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.448.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12484.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.460.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.474.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.312.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.90.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.53.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.138.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.47.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.104.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.111.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.105.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.46.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.139.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.52.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.85.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.91.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.313.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.307.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.461.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.449.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12485.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12491.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12308.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12320.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12446.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12452.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12334.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.267.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.273.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12283.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.529.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12254.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12240.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.259.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12295.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12281.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.265.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.503.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.517.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12444.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.488.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12322.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12336.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12450.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12487.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12493.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.339.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.311.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.305.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.87.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.50.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.78.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.113.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.106.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.112.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.79.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.51.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.45.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.86.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.462.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.304.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.310.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.476.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.338.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12492.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12479.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12451.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12323.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.489.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.270.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.264.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.502.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12280.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12294.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12243.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12253.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12247.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.506.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.260.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.274.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.512.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.248.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12284.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12469.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12327.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12441.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.499.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.472.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.314.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.300.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12482.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12496.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.82.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.96.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.116.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.69.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.102.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.41.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.55.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.54.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.40.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.103.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.68.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.117.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.97.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.83.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12497.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12483.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.329.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.467.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.473.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12454.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12332.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12440.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12468.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.249.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12285.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12291.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.513.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.507.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.261.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12246.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12252.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12278.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12244.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.288.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12250.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.511.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.277.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.505.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12287.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12293.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.539.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12318.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12330.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12456.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12442.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.465.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.303.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.471.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.459.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12495.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12481.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.95.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.101.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.115.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.56.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.129.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.128.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.43.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.57.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.114.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.100.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.80.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12480.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.458.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.316.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.470.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.464.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.302.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12443.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12325.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12457.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12319.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.538.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12292.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12286.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.262.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.504.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.276.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12251.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.289.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12260.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12274.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12248.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.284.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.509.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.253.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.535.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.521.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.247.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12472.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12314.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12300.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12328.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.482.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.496.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.469.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.327.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.441.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.455.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.333.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.72.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.119.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.66.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.125.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.131.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.130.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.124.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.67.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.118.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.73.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.98.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.454.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12498.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.332.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.326.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.440.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.468.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.497.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.483.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12329.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12301.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12467.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12473.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12315.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.520.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.246.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.252.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.534.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.508.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12249.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.285.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.291.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12275.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12261.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12277.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12263.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.287.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.293.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.278.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.244.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12288.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.536.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12465.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12303.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12317.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12471.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12459.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.495.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.318.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.330.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.456.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.442.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.324.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.65.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.71.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.59.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.132.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.126.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.127.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.133.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.70.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.64.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.443.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.325.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.331.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.457.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.319.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.480.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12458.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.494.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12316.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12470.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.251.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.245.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.523.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12289.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.292.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.286.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.282.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.296.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12272.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12266.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.527.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.241.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.533.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12299.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.269.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12448.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.484.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12474.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12312.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.453.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.335.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.309.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.48.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.123.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.60.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.74.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.122.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.49.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.136.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.320.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.446.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.452.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12307.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12461.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12449.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.268.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.254.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12298.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.532.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.240.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12267.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12273.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.283.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12259.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.295.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.281.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12265.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12271.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.530.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.256.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.242.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.524.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.518.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.487.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.493.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12477.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12305.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.444.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.322.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.336.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.450.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.88.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.120.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.134.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.63.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.109.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.62.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.76.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.135.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.121.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.89.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.479.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.337.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.445.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.323.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12489.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12304.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12310.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12476.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12338.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.492.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.519.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.243.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.525.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.531.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.257.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12264.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.280.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12258.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.595.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.218.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.556.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.230.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.542.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12377.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12411.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.387.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12439.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.378.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.422.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.350.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.185.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.191.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.146.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.152.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.153.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.38.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.147.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.609.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.190.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.184.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.437.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.423.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.345.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.379.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12438.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.392.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12404.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12362.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12376.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12410.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.225.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.543.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.557.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.231.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.219.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.580.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.594.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.582.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.569.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.541.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.227.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.555.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12360.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12406.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12412.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12374.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.384.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12348.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.353.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.347.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.421.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.192.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.179.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.151.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.145.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.144.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.150.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.178.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.13.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.187.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.193.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.346.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.420.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.434.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.408.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.385.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12349.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.391.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12413.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12375.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12361.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12407.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.232.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.540.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.226.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.568.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.597.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.583.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.9.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.587.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.222.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.550.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.578.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.395.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12359.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.381.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12403.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12365.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12371.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12417.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.356.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.430.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.424.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.342.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.418.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.197.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.183.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.154.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.140.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.168.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.17.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.16.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.141.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.155.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.182.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.196.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.419.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.425.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.343.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.357.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.431.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12370.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12416.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12364.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.380.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.394.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12358.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.551.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.237.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.223.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.592.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.586.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.8.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.590.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.584.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.553.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.547.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.221.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.209.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12428.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.382.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12414.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12372.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12366.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.341.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.427.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12399.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.355.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.369.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.180.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.194.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.28.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.157.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.14.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.15.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.156.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.142.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.29.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.181.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.368.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.354.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.426.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12367.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12415.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.12373.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.397.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.383.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.208.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.546.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.220.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.234.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.585.jpg'),
#  PosixPath('cat_dog_images/gatinho/cat.591.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12379.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12437.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12351.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12345.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12392.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12386.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.211.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.577.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.563.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.205.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.239.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.588.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.365.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.417.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.371.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.359.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.167.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.173.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.615.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.22.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.629.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.198.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.199.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.628.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.23.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.37.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.172.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.614.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.600.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.166.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.358.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.416.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.370.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.364.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.402.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.562.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.204.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.576.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12387.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12393.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12344.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12422.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12436.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12350.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12408.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12420.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12346.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12434.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12385.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.206.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.574.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.212.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.548.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.372.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.400.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.428.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.399.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.616.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.170.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.164.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.21.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.158.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.35.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.159.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.165.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.603.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.171.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.429.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.367.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.373.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.415.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.575.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.213.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.207.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12390.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12353.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12435.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12421.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12347.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12409.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12343.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12425.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12431.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12357.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12419.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12380.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12394.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.559.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.565.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.203.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.217.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.571.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.439.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.411.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.377.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.405.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.388.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.149.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.24.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.175.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.613.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.18.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.607.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.161.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.606.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.160.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.174.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.19.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.612.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.31.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.148.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.25.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.362.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.404.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.410.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.376.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.438.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.570.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.564.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.202.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.558.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12395.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12381.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12418.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12430.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12356.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12342.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12424.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12354.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12432.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12368.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12397.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.228.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.572.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.200.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.599.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.360.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.374.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.412.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.33.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.162.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.610.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.188.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.177.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.163.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.605.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.26.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.32.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.375.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.407.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.361.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.349.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.598.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.201.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.573.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.215.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.229.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12382.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12396.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12369.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12427.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12341.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12355.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12433.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12468.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12332.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12454.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12440.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12326.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12497.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12483.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.514.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.272.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.528.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.299.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.460.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.312.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.474.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.448.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.110.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.138.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12246.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.55.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.1.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.41.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12285.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.96.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.82.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12291.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.83.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12290.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.97.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.40.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.0.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12253.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12247.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.54.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.111.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.68.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.449.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.475.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.307.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.298.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.529.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.267.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.515.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.273.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12482.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12441.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12327.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12455.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12469.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12319.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12457.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12480.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12494.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.503.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.265.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.271.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.517.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.259.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.311.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.305.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.463.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.488.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.113.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.107.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12251.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.2.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.42.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12292.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.81.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.95.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.94.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12287.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12293.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.80.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.57.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.43.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.3.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12278.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.112.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.489.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.338.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.304.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.462.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.476.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.310.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.258.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.270.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.516.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.502.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12495.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12481.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12330.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12442.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12318.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12320.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12334.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12452.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12308.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12485.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.248.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.260.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.512.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.328.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.314.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.466.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.300.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.499.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.47.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.7.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.53.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.116.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12268.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.102.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12297.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12283.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12282.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.91.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.85.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12296.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.103.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12269.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.117.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.52.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.6.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.46.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.498.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.301.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.315.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.473.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.329.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.513.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.275.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.261.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.507.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.249.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12490.jpg'),
#  PosixPath('cat_dog_images/cachorinho/dog.12484.jpg'),
#  ...]

# %% [markdown]
# ## Tratando os dados
#
# Como próximo passo, vamos armazenar as **targets** do nosso modelo e as **imagens** em uma **lista**. Para todas as imagens localizadas em filepaths, vamos percorrer com um **loop cada uma das imagens e realizar algumas tratativas** como por exemplo redimensionar a imagem e normalizar o intervalo de pixels para ficar entre 0 e 1 e armazena-las nas listas.
#
# Aqui é importante relembrar que redes neurais funcionam melhor quando estão com os dados normalizados ou padronizados.

# %%
# Inicializando rótulos e listas de imagens para armazenar os dados
labels = [] #armazenando as variáveis target
images = [] #armazenando imagens

# Definindo o tamanho da dimensão da imagem
image_size = 64

# Um loop for para definir as variáveis x e y para os modelos
for filepath in filepaths:
    # Divide o nome do caminho para extrair o cabeçalho do caminho com split
    head = os.path.split(filepath)
    # Divide o cabeçalho do caminho anterior para extrair o nome do animal
    animal = os.path.split(head[0])
    # Armazena o nome do animal na lista de labels
    labels.append(animal[1])
    # Obtem a imagem do caminho com cv2
    img = cv2.imread(str(filepath))
    # Redimensiona a imagem e normalize o intervalo de pixels para ficar entre 0 e 1 (padronização)
    # Utilizando float32 para criar uma precisão limitada (menor demanda de memória em comparação com tipos de ponto flutuante de maior precisão: float64)
    img = cv2.resize(img, (image_size, image_size)).astype('float32') / 255.0
    # Adiciona a imagem na lista de imagens
    images.append(img)

# Converte a imagem em lista de array
images = np.array(images)
# Converte as labels para lista de array
labels = np.array(labels)

# %% [markdown]
# Muito bem! Agora temos as imagens armazenadas em um formato de um grande array na variável "images" e os rótulos em "labels".

# %%
images.shape
# Out:
# (1400, 64, 64, 3)

# %%
images
# Out:
# array([[[[0.7647059 , 0.7254902 , 0.8235294 ],
#          [0.7607843 , 0.7176471 , 0.81960785],
#          [0.7607843 , 0.7176471 , 0.81960785],
#          ...,
#          [0.6431373 , 0.65882355, 0.63529414],
#          [0.8392157 , 0.79607844, 0.7411765 ],
#          [0.7764706 , 0.7490196 , 0.7490196 ]],
#
#         [[0.75686276, 0.72156864, 0.8039216 ],
#          [0.7607843 , 0.7254902 , 0.80784315],
#          [0.7607843 , 0.7254902 , 0.80784315],
#          ...,
#          [0.6509804 , 0.65882355, 0.6392157 ],
#          [0.81960785, 0.78431374, 0.7137255 ],
#          [0.72156864, 0.70980394, 0.7372549 ]],
#
#         [[0.9372549 , 0.9254902 , 0.9372549 ],
#          [0.9254902 , 0.9137255 , 0.9254902 ],
#          [0.94509804, 0.93333334, 0.94509804],
#          ...,
#          [0.6509804 , 0.64705884, 0.6431373 ],
#          [0.8117647 , 0.7921569 , 0.70980394],
#          [0.60784316, 0.6156863 , 0.68235296]],
#
#         ...,
#
#         [[0.19215687, 0.14901961, 0.5137255 ],
#          [0.1882353 , 0.14509805, 0.5058824 ],
#          [0.19607843, 0.14901961, 0.49019608],
#          ...,
#          [0.2       , 0.10588235, 0.32941177],
#          [0.16470589, 0.10980392, 0.2509804 ],
#          [0.19607843, 0.1254902 , 0.38431373]],
#
#         [[0.1882353 , 0.15294118, 0.49411765],
#          [0.18431373, 0.14901961, 0.49019608],
#          [0.1882353 , 0.14901961, 0.5058824 ],
#          ...,
#          [0.18431373, 0.09411765, 0.38039216],
#          [0.16078432, 0.11372549, 0.29803923],
#          [0.1882353 , 0.12156863, 0.34117648]],
#
#         [[0.18039216, 0.13725491, 0.49803922],
#          [0.1764706 , 0.13333334, 0.49411765],
#          [0.1764706 , 0.12941177, 0.49019608],
#          ...,
#          [0.16078432, 0.09411765, 0.3764706 ],
#          [0.17254902, 0.10588235, 0.37254903],
#          [0.19607843, 0.10980392, 0.39607844]]],
#
#
#        [[[0.90588236, 0.90588236, 0.9137255 ],
#          [0.95686275, 0.95686275, 0.9607843 ],
#          [0.92156863, 0.92156863, 0.92941177],
#          ...,
#          [0.75686276, 0.7607843 , 0.7921569 ],
#          [0.38431373, 0.42745098, 0.4509804 ],
#          [0.20784314, 0.19607843, 0.21960784]],
#
#         [[0.6745098 , 0.6901961 , 0.69411767],
#          [0.7176471 , 0.73333335, 0.7372549 ],
#          [0.6901961 , 0.70980394, 0.7137255 ],
#          ...,
#          [0.80784315, 0.8156863 , 0.8509804 ],
#          [0.42352942, 0.41568628, 0.4509804 ],
#          [0.18039216, 0.16862746, 0.19215687]],
#
#         [[0.74509805, 0.7607843 , 0.7607843 ],
#          [0.7411765 , 0.7529412 , 0.75686276],
#          [0.7254902 , 0.73333335, 0.7372549 ],
#          ...,
#          [0.70980394, 0.7411765 , 0.77254903],
#          [0.5137255 , 0.4862745 , 0.5254902 ],
#          [0.18039216, 0.1882353 , 0.20784314]],
#
#         ...,
#
#         [[0.5647059 , 0.50980395, 0.5254902 ],
#          [0.84313726, 0.7882353 , 0.80784315],
#          [0.6156863 , 0.56078434, 0.5764706 ],
#          ...,
#          [0.2627451 , 0.23921569, 0.23921569],
#          [0.31764707, 0.29411766, 0.29803923],
#          [0.3254902 , 0.3372549 , 0.35686275]],
#
#         [[0.5411765 , 0.48235294, 0.5137255 ],
#          [0.85882354, 0.8       , 0.83137256],
#          [0.5137255 , 0.45490196, 0.49019608],
#          ...,
#          [0.15686275, 0.13333334, 0.13725491],
#          [0.2       , 0.17254902, 0.18039216],
#          [0.2509804 , 0.23529412, 0.25882354]],
#
#         [[0.54509807, 0.48235294, 0.5254902 ],
#          [0.6666667 , 0.6039216 , 0.64705884],
#          [0.6392157 , 0.5764706 , 0.61960787],
#          ...,
#          [0.12941177, 0.10588235, 0.10980392],
#          [0.1764706 , 0.15294118, 0.15686275],
#          [0.20784314, 0.16862746, 0.2       ]]],
#
#
#        [[[0.65882355, 0.63529414, 0.73333335],
#          [0.654902  , 0.64705884, 0.70980394],
#          [0.6862745 , 0.6745098 , 0.73333335],
#          ...,
#          [0.21960784, 0.23137255, 0.27058825],
#          [0.24313726, 0.25882354, 0.28235295],
#          [0.19215687, 0.19607843, 0.2       ]],
#
#         [[0.70980394, 0.6901961 , 0.77254903],
#          [0.73333335, 0.72156864, 0.8       ],
#          [0.73333335, 0.7019608 , 0.7647059 ],
#          ...,
#          [0.20392157, 0.2509804 , 0.32941177],
#          [0.20392157, 0.23529412, 0.30588236],
#          [0.19607843, 0.21568628, 0.2784314 ]],
#
#         [[0.69411767, 0.68235296, 0.7490196 ],
#          [0.6627451 , 0.64705884, 0.7372549 ],
#          [0.77254903, 0.73333335, 0.8       ],
#          ...,
#          [0.30980393, 0.34901962, 0.42352942],
#          [0.31764707, 0.34117648, 0.41568628],
#          [0.3254902 , 0.34117648, 0.4       ]],
#
#         ...,
#
#         [[0.7294118 , 0.75686276, 0.8235294 ],
#          [0.72156864, 0.7294118 , 0.8       ],
#          [0.7254902 , 0.75686276, 0.8235294 ],
#          ...,
#          [0.53333336, 0.58431375, 0.64705884],
#          [0.54509807, 0.6039216 , 0.6392157 ],
#          [0.5019608 , 0.5529412 , 0.627451  ]],
#
#         [[0.7058824 , 0.7372549 , 0.7921569 ],
#          [0.7529412 , 0.7647059 , 0.81960785],
#          [0.7254902 , 0.74509805, 0.8       ],
#          ...,
#          [0.5529412 , 0.6039216 , 0.6666667 ],
#          [0.5254902 , 0.58431375, 0.62352943],
#          [0.5294118 , 0.5803922 , 0.654902  ]],
#
#         [[0.7176471 , 0.75686276, 0.79607844],
#          [0.7490196 , 0.7647059 , 0.80784315],
#          [0.77254903, 0.78039217, 0.8235294 ],
#          ...,
#          [0.5686275 , 0.61960787, 0.68235296],
#          [0.54901963, 0.60784316, 0.6431373 ],
#          [0.54509807, 0.59607846, 0.6666667 ]]],
#
#
#        ...,
#
#
#        [[[0.44313726, 0.48235294, 0.54901963],
#          [0.7019608 , 0.7411765 , 0.8       ],
#          [0.9843137 , 0.99215686, 0.99215686],
#          ...,
#          [0.15686275, 0.14901961, 0.17254902],
#          [0.16862746, 0.18039216, 0.19607843],
#          [0.2784314 , 0.28235295, 0.32156864]],
#
#         [[0.46666667, 0.5176471 , 0.5764706 ],
#          [0.7058824 , 0.75686276, 0.8156863 ],
#          [0.98039216, 0.99607843, 0.99607843],
#          ...,
#          [0.16078432, 0.15686275, 0.19215687],
#          [0.18431373, 0.19607843, 0.21568628],
#          [0.27058825, 0.2784314 , 0.3137255 ]],
#
#         [[0.45490196, 0.5137255 , 0.5764706 ],
#          [0.6862745 , 0.7490196 , 0.8039216 ],
#          [0.88235295, 0.9098039 , 0.9098039 ],
#          ...,
#          [0.16470589, 0.17254902, 0.20392157],
#          [0.20784314, 0.21176471, 0.2509804 ],
#          [0.33333334, 0.34509805, 0.3647059 ]],
#
#         ...,
#
#         [[0.6745098 , 0.7647059 , 0.8117647 ],
#          [0.7490196 , 0.827451  , 0.8784314 ],
#          [0.7529412 , 0.81960785, 0.87058824],
#          ...,
#          [0.41960785, 0.40392157, 0.42745098],
#          [0.05098039, 0.04313726, 0.09019608],
#          [0.17254902, 0.2       , 0.24313726]],
#
#         [[0.67058825, 0.76862746, 0.8156863 ],
#          [0.69803923, 0.7882353 , 0.83137256],
#          [0.7647059 , 0.8392157 , 0.8901961 ],
#          ...,
#          [0.2627451 , 0.24705882, 0.28235295],
#          [0.03921569, 0.03921569, 0.09411765],
#          [0.21176471, 0.23921569, 0.2901961 ]],
#
#         [[0.7137255 , 0.7764706 , 0.8392157 ],
#          [0.7019608 , 0.7647059 , 0.827451  ],
#          [0.7372549 , 0.8       , 0.8627451 ],
#          ...,
#          [0.07058824, 0.0627451 , 0.10196079],
#          [0.07843138, 0.09019608, 0.14901961],
#          [0.1764706 , 0.20392157, 0.2627451 ]]],
#
#
#        [[[0.2901961 , 0.3137255 , 0.4       ],
#          [0.23921569, 0.2784314 , 0.3254902 ],
#          [0.21568628, 0.28627452, 0.30588236],
#          ...,
#          [0.1254902 , 0.2       , 0.14117648],
#          [0.10196079, 0.1882353 , 0.13725491],
#          [0.14509805, 0.23137255, 0.21176471]],
#
#         [[0.1254902 , 0.19215687, 0.2       ],
#          [0.07843138, 0.14901961, 0.14117648],
#          [0.14509805, 0.22745098, 0.21176471],
#          ...,
#          [0.07843138, 0.16078432, 0.11372549],
#          [0.11764706, 0.20784314, 0.1764706 ],
#          [0.20784314, 0.30588236, 0.28627452]],
#
#         [[0.09411765, 0.2       , 0.13333334],
#          [0.07450981, 0.17254902, 0.11764706],
#          [0.10980392, 0.21176471, 0.16078432],
#          ...,
#          [0.10196079, 0.19215687, 0.16078432],
#          [0.15686275, 0.25490198, 0.23921569],
#          [0.05098039, 0.16862746, 0.14509805]],
#
#         ...,
#
#         [[0.5764706 , 0.59607846, 0.654902  ],
#          [0.6156863 , 0.62352943, 0.6666667 ],
#          [0.6313726 , 0.6313726 , 0.6745098 ],
#          ...,
#          [0.29803923, 0.3372549 , 0.3647059 ],
#          [0.23921569, 0.27058825, 0.3137255 ],
#          [0.15294118, 0.19215687, 0.25882354]],
#
#         [[0.5921569 , 0.5921569 , 0.6392157 ],
#          [0.6       , 0.6       , 0.6509804 ],
#          [0.60784316, 0.60784316, 0.654902  ],
#          ...,
#          [0.34117648, 0.39215687, 0.40392157],
#          [0.19215687, 0.22352941, 0.25882354],
#          [0.23137255, 0.25490198, 0.30588236]],
#
#         [[0.5921569 , 0.5921569 , 0.6392157 ],
#          [0.58431375, 0.58431375, 0.6313726 ],
#          [0.59607846, 0.59607846, 0.6431373 ],
#          ...,
#          [0.2509804 , 0.30588236, 0.35686275],
#          [0.25490198, 0.28627452, 0.34117648],
#          [0.32941177, 0.3647059 , 0.4       ]]],
#
#
#        [[[0.01568628, 0.01960784, 0.01176471],
#          [0.01176471, 0.01568628, 0.00784314],
#          [0.        , 0.01176471, 0.00392157],
#          ...,
#          [0.5411765 , 0.61960787, 0.6156863 ],
#          [0.49019608, 0.5803922 , 0.5647059 ],
#          [0.50980395, 0.5921569 , 0.59607846]],
#
#         [[0.01176471, 0.01568628, 0.00784314],
#          [0.00784314, 0.01176471, 0.00392157],
#          [0.01176471, 0.00392157, 0.        ],
#          ...,
#          [0.5647059 , 0.69411767, 0.6627451 ],
#          [0.5686275 , 0.6666667 , 0.6156863 ],
#          [0.627451  , 0.7058824 , 0.67058825]],
#
#         [[0.01568628, 0.01960784, 0.01176471],
#          [0.01568628, 0.01960784, 0.01176471],
#          [0.01176471, 0.01960784, 0.        ],
#          ...,
#          [0.74509805, 0.7882353 , 0.75686276],
#          [0.72156864, 0.7764706 , 0.7372549 ],
#          [0.74509805, 0.8       , 0.76862746]],
#
#         ...,
#
#         [[0.2627451 , 0.3764706 , 0.36078432],
#          [0.57254905, 0.69803923, 0.69411767],
#          [0.5058824 , 0.62352943, 0.6392157 ],
#          ...,
#          [0.4627451 , 0.7372549 , 0.61960787],
#          [0.49019608, 0.73333335, 0.6627451 ],
#          [0.56078434, 0.6627451 , 0.6666667 ]],
#
#         [[0.5294118 , 0.65882355, 0.6313726 ],
#          [0.45882353, 0.6156863 , 0.57254905],
#          [0.38431373, 0.5764706 , 0.49019608],
#          ...,
#          [0.23137255, 0.30980393, 0.32941177],
#          [0.18431373, 0.26666668, 0.27058825],
#          [0.19215687, 0.24313726, 0.25882354]],
#
#         [[0.5137255 , 0.6509804 , 0.6117647 ],
#          [0.38431373, 0.5686275 , 0.5137255 ],
#          [0.56078434, 0.6862745 , 0.69803923],
#          ...,
#          [0.5686275 , 0.65882355, 0.67058825],
#          [0.23921569, 0.3254902 , 0.34117648],
#          [0.32941177, 0.39607844, 0.4117647 ]]]], dtype=float32)

# %%
labels
# Out:
# array(['gatinho', 'gatinho', 'gatinho', ..., 'cachorinho', 'cachorinho',
#        'cachorinho'], dtype='<U10')

# %% [markdown]
# ## Construindo um dataframe
#
# Com as imagens e rotulos já definidos, vamos construir um dataframe com o nome do caminho e o rótulo da imagem.

# %%
# Salvando a lista de caminhos de arquivo
pd_filepaths = pd.Series(filepaths, name='Filepath').astype(str)

# %%
# Visualizando o camiho das imagens
print(pd_filepaths[:3])
# Out:
# 0      cat_dog_images/gatinho/cat.6.jpg
# 1    cat_dog_images/gatinho/cat.588.jpg
# 2    cat_dog_images/gatinho/cat.239.jpg
# Name: Filepath, dtype: object

# %%
# Visualizando os rótulos das imagens
print(labels[:3])
# Out:
# ['gatinho' 'gatinho' 'gatinho']

# %%
# Adicionando a label
pd_labels = pd.Series(labels, name='Label')

# %%
# Concatenando the filepaths and labels
df = pd.concat([pd_filepaths, pd_labels], axis=1)

# %%
df.head()
# Out:
#                              Filepath    Label
# 0    cat_dog_images/gatinho/cat.6.jpg  gatinho
# 1  cat_dog_images/gatinho/cat.588.jpg  gatinho
# 2  cat_dog_images/gatinho/cat.239.jpg  gatinho
# 3  cat_dog_images/gatinho/cat.577.jpg  gatinho
# 4  cat_dog_images/gatinho/cat.211.jpg  gatinho

# %%
df.tail()
# Out:
#                                      Filepath       Label
# 1395  cat_dog_images/cachorinho/dog.12348.jpg  cachorinho
# 1396  cat_dog_images/cachorinho/dog.12406.jpg  cachorinho
# 1397  cat_dog_images/cachorinho/dog.12360.jpg  cachorinho
# 1398  cat_dog_images/cachorinho/dog.12374.jpg  cachorinho
# 1399  cat_dog_images/cachorinho/dog.12412.jpg  cachorinho

# %% [markdown]
# Perceba que nossos dados estão em ordem das classes, isso pode ser um problema para o modelo, então vamos utilizar o sample para embaralhar o dataframe:

# %%
# Embaralhando o dataframe
df = df.sample(frac=1).reset_index(drop = True)

# %%
df.head()
# Out:
#                                   Filepath       Label
# 0    cat_dog_images/cachorinho/dog.226.jpg  cachorinho
# 1    cat_dog_images/cachorinho/dog.420.jpg  cachorinho
# 2    cat_dog_images/cachorinho/dog.613.jpg  cachorinho
# 3        cat_dog_images/gatinho/cat.31.jpg     gatinho
# 4  cat_dog_images/cachorinho/dog.12288.jpg  cachorinho

# %%
# Cria uma cópia do dataframe com apenas uma imagem de cada personagem
df_singles = df.copy().drop_duplicates(subset=('Label')).reset_index() # o subset está procurando por duplicatas apenas na coluna chamada 'Label' e removendo todas as duplicatas encontradas.

# %%
len(df_singles)
# Out:
# 2

# %%
# Define o número de classes
num_classes = df_singles.shape[0]

# %%
num_classes
# Out:
# 2

# %% [markdown]
# Show! agora que temos as classes mapeadas na variável num_classes, vamos visualizar duas amostras de imagens dentro do dataset:

# %%
# Configura o número de linhas e colunas para visualizar os dados no plot
ROW = 1
COLUMN = 2

# Dimensões das imagens
plt.figure(figsize=(12, 9))
#Loop para cada animal
for i in range(num_classes):
    # Defina uma variável de imagem local para i imagem no dataframe de singles
    image = df_singles.Filepath[i]
    # Define a posição da imagem a ser plotada
    plt.subplot(ROW, COLUMN, i+1)
    # Mostra a imagem
    plt.imshow(plt.imread(image))
    # Adiciona o rótulo do bichinho que corresponde à imagem
    plt.title('{}'.format(df_singles.Label[i]))
    # Desliga o eixo de plotagem
    plt.axis('off')
    # Faça com que o preenchimento ao redor das imagens seja mínimo
    plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separando em treino e teste a base de dados
#
# Agora com as imagens e classes organizadas, podemos aplicar o train_test_split para separar as bases de treinamento e teste:

# %%
x_train, x_test, y_train, y_test = train_test_split(images,
                                           labels, test_size=0.2, stratify=labels, random_state=44)

# %%
# Analisando a dimensão dos dados
x_train.shape
# Out:
# (1120, 64, 64, 3)

# %%
x_test.shape
# Out:
# (280, 64, 64, 3)

# %% [markdown]
# Sabemos que as imagens são basicamente uma matriz de pixels e para colocar as imagens dentro da arquitetura das redes convolucionais, é preciso "achatar" essas matrizes multidimensionais em vetores unidimensionais. Uma das camadas da rede, a Flatten(), é uma das partes da rede que achata os dados antes de entrar nas camadas densas.

# %%
# Achatar os dados de teste e treinamento
x_train_flat = x_train.reshape(x_train.shape[0], x_train.shape[1]* x_train.shape[2]* x_train.shape[3])
x_test_flat = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2] * x_test.shape[3])

# %%
# Visualizando a transformação
x_train_flat.shape
# Out:
# (1120, 12288)

# %% [markdown]
# Como próximo passo, vamos converter as classes de texto em binárias. Para esse procedimento, vamos utilizar o método LabelEncoder().

# %%
# Converter Strings em Numéricos
label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.fit_transform(y_test)

# Converte um vetor de classe (inteiros) em uma matriz de classe categórica.
y_train_tf = keras.utils.to_categorical(y_train, num_classes)
y_test_tf = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
#  Vamos configurar agora como próximo passo o ModelCheckpoint para usar os melhores pesos para este modelo. Um dos benefícios do ModelCheckpoint é salvar uma cópia do modelo em disco em intervalos regulares (como após cada época de processamento) para que você possa retomar o treinamento a partir do ponto em que parou, minimizando perdas de tempo e recursos computacionais.

# %%
from distutils.file_util import copy_file

# Defina um objeto ModelCheckpoint para usar os melhores pesos para este modelo
checkpointer = ModelCheckpoint(filepath="cat_dog_images/weights.best.hdf5", verbose=0, save_best_only=True) # save best model

# %% [markdown]
# Como próximo passo, vamos definir a entrada da rede e armazenar na variável **input_shape** e em seguida configurar a learning rate e a queda do peso do otimizador com **weight_decay**.
#
#
# O argumento weight_decay é usado para aplicar **regularização L2** (também conhecida como regularização de peso) às camadas densas (fully connected) de uma rede neural durante o treinamento. A regularização L2 funciona adicionando um termo à função de perda durante o treinamento que penaliza os pesos maiores.

# %%
# Define a forma de entrada das imagens passadas pelo modelo
input_shape = (image_size, image_size, 3)

# Defina a taxa de aprendizado e a queda de peso para o otimizador usar
learning_rate = 0.001
weight_decay = 1e-4

# %% [markdown]
# Agora chegou o momento tão esperado, nossa rede neural convolucional! 🦾
#
# Acompanhe comigo o código a seguir e vamos comentando sobre cada passo da construção da rede:

# %%
tf.random.set_seed(44) # Defindo uma semente aleatória para utilizar sempre os mesmos dados durante nossos testes

model = Sequential() # Abrindo a sequencia do modelo

# 1 camada convolucional com 128 neurônios | filtro utilizando uma matriz 3x3 sendo movimentado por um stride de 2
# padding ativado (sem bordas de zeros) | função de ativação ReLU | regularização L2 ativada
model.add(Conv2D(128,
                 kernel_size=(3, 3),
                 strides=(2, 2),
                 padding='same',
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(0.001),
                 input_shape=input_shape)),

# Camada de MaxPolling ativada, com uma matriz 2x2. Padding ativado
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))

# Regularização de dropout ativada
model.add(Dropout(0.5))

# 2 camada convolucional com 92 neurônios | filtro utilizando uma matriz 3x3 sendo movimentado por um stride de 2
# padding ativado (sem bordas de zeros) | função de ativação ReLU | regularização L2 ativada
model.add(Conv2D(92,
                 kernel_size=(3, 3),
                 strides=(2, 2),
                 padding='same',
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(0.001))),

# Camada de MaxPolling ativada, com uma matriz 2x2. Padding ativado
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))

# Regularização de dropout ativada
model.add(Dropout(0.5))

# Camada que achata dos dados da imagem
model.add(Flatten())
# Camada Dense da rede neural convolucional + função de ativação ReLU
model.add(Dense(256, activation='relu'))
# Camada de saída da rede, utilizando a função de ativação softmax para criar a probabilidade de pertencimento das classes
model.add(Dense(y_train_tf.shape[1], activation='softmax'))

# %% [markdown]
# Agora vamos configurar uma técnica de validação do modelo para evitar que as épocas de processamento não executem o modelo sem ter melhoras significativas, o **early stopping**. Essa técnica monitora a perda no conjunto de validação e interrompe o treinamento se a perda não diminuir significativamente por um número especificado de épocas (10 no exemplo) após uma pequena melhoria (mínimo delta de 1e-5). Essa é uma **técnica útil para evitar o overfitting e economizar tempo de treinamento**. (Podemos dizer que essa técnica ajuda o modelo a não ficar "estagnado", ou seja, se encontra em estado estacionário).
#
# Além da configuração do early stopping, vamos configurar a função de custo com o **Adam**. A função de custo tem o papel de **ajustar os pesos de uma rede neural durante o treinamento**. o Adam também utiliza um termo de momentum para acelerar o processo de aprendizado. O momentum **ajuda o algoritmo a superar regiões planas ou mínimos locais rasos**, permitindo que ele "ganhe velocidade" na direção do mínimo global. O otimizador Adam requer menos configuração de hiperparâmetro da taxa de aprendizagem, então um valor padrão n = 0,001 pode ser uma boa opção!
#
# Lembrando que a **taxa de aprendizagem** (learning rate) é responsável por  controlar o tamanho dos “passos” das interações para encontrar um melhor mínimo local (menor erro). Uma taxa de aprendizagem baixa pode ser mais precisa, porém pode demorar para encontrar o mínimo local. Uma taxa de aprendizado alta pode deixar passar o melhor mínimo local.

# %%
# Monitor para interromper o modelo antecipadamente quando a melhoria da perda de validação for mínima
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=10, verbose=1, mode='auto') #Aqui utilizando early stopping

# Compilando o modelo e aplicação a função de custo Adam (utilizando a learning rate que configuramos anteriormente)
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate), metrics=['accuracy'])

# Salve os dados do modelo em um arquivo h5
model.save('./cat_dog_images/cat_dog.h5')
# Resumo do modelo
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_72 (Conv2D)          (None, 32, 32, 128)       3584
#
#  max_pooling2d_72 (MaxPooli  (None, 16, 16, 128)       0
#  ng2D)
#
#  dropout_72 (Dropout)        (None, 16, 16, 128)       0
#
#  conv2d_73 (Conv2D)          (None, 8, 8, 92)          106076
#
#  max_pooling2d_73 (MaxPooli  (None, 4, 4, 92)          0
#  ng2D)
#
#  dropout_73 (Dropout)        (None, 4, 4, 92)          0
#
#  flatten_23 (Flatten)        (None, 1472)              0
#
#  dense_46 (Dense)            (None, 256)               377088
#
#  dense_47 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 487262 (1.86 MB)
# Trainable params: 487262 (1.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /Users/marcelocardoso/Documents/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Por fim, vamos configurar o número de épocas de processamento em conjunto com a base de validação das épocas. Nesse momento também é importante configurar o número de batchs que o modelo irá processar por épocas para atualizar os pesos. Em outras palavras, as batchs são as quantidades de dados de treinamento que são processadas de uma só vez antes que os pesos do modelo sejam atualizados com base nos gradientes calculados.

# %%
# Treinando o modelo
history = model.fit(x_train,y_train_tf, validation_split=0.25, callbacks=[monitor,checkpointer],
                    verbose=1,epochs=45, batch_size=50, shuffle=True)
# Out:
# Epoch 1/40
# 17/17 [==============================] - 1s 39ms/step - loss: 0.8100 - accuracy: 0.4869 - val_loss: 0.7852 - val_accuracy: 0.4964
# Epoch 2/40
# 17/17 [==============================] - 1s 46ms/step - loss: 0.7740 - accuracy: 0.5333 - val_loss: 0.7604 - val_accuracy: 0.5607
# Epoch 3/40
# 17/17 [==============================] - 1s 35ms/step - loss: 0.7559 - accuracy: 0.5583 - val_loss: 0.7475 - val_accuracy: 0.5107
# Epoch 4/40
# 17/17 [==============================] - 1s 36ms/step - loss: 0.7500 - accuracy: 0.5536 - val_loss: 0.7396 - val_accuracy: 0.5643
# Epoch 5/40
# 17/17 [==============================] - 1s 31ms/step - loss: 0.7437 - accuracy: 0.5190 - val_loss: 0.7361 - val_accuracy: 0.5286
# Epoch 6/40
# 17/17 [==============================] - 1s 32ms/step - loss: 0.7306 - accuracy: 0.5619 - val_loss: 0.7114 - val_accuracy: 0.6571
# Epoch 7/40
# 17/17 [==============================] - 1s 34ms/step - loss: 0.7080 - accuracy: 0.6167 - val_loss: 0.6904 - val_accuracy: 0.6643
# Epoch 8/40
# 17/17 [==============================] - 1s 32ms/step - loss: 0.6853 - accuracy: 0.6429 - val_loss: 0.6874 - val_accuracy: 0.6536
# Epoch 9/40
# 17/17 [==============================] - 1s 34ms/step - loss: 0.6558 - accuracy: 0.6619 - val_loss: 0.6582 - val_accuracy: 0.6643
# Epoch 10/40
# 17/17 [==============================] - 1s 32ms/step - loss: 0.6383 - accuracy: 0.6655 - val_loss: 0.7510 - val_accuracy: 0.5786
# Epoch 11/40
# 17/17 [==============================] - 1s 36ms/step - loss: 0.6505 - accuracy: 0.6702 - val_loss: 0.6480 - val_accuracy: 0.6714
# Epoch 12/40
# 17/17 [==============================] - 1s 31ms/step - loss: 0.6065 - accuracy: 0.7071 - val_loss: 0.6382 - val_accuracy: 0.6821
# Epoch 13/40
# 17/17 [==============================] - 1s 36ms/step - loss: 0.5906 - accuracy: 0.7274 - val_loss: 0.6606 - val_accuracy: 0.6929
# Epoch 14/40
# 17/17 [==============================] - 1s 39ms/step - loss: 0.6086 - accuracy: 0.6952 - val_loss: 0.6949 - val_accuracy: 0.6393
# Epoch 15/40
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5662 - accuracy: 0.7488 - val_loss: 0.6343 - val_accuracy: 0.6714
# Epoch 16/40
# 17/17 [==============================] - 1s 33ms/step - loss: 0.5573 - accuracy: 0.7571 - val_loss: 0.6598 - val_accuracy: 0.6643
# Epoch 17/40
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5266 - accuracy: 0.7595 - val_loss: 0.6733 - val_accuracy: 0.6893
# Epoch 18/40
# 17/17 [==============================] - 1s 31ms/step - loss: 0.5249 - accuracy: 0.7810 - val_loss: 0.6527 - val_accuracy: 0.6643
# Epoch 19/40
# 17/17 [==============================] - 1s 35ms/step - loss: 0.5047 - accuracy: 0.7810 - val_loss: 0.6697 - val_accuracy: 0.6964
# Epoch 20/40
# 17/17 [==============================] - 1s 31ms/step - loss: 0.5038 - accuracy: 0.7857 - val_loss: 0.6406 - val_accuracy: 0.7143
# Epoch 21/40
# 17/17 [==============================] - 1s 32ms/step - loss: 0.4917 - accuracy: 0.7964 - val_loss: 0.6455 - val_accuracy: 0.6679
# Epoch 22/40
# 17/17 [==============================] - 1s 31ms/step - loss: 0.4933 - accuracy: 0.8000 - val_loss: 0.6694 - val_accuracy: 0.6893
# Epoch 23/40
# 17/17 [==============================] - 1s 34ms/step - loss: 0.4406 - accuracy: 0.8310 - val_loss: 0.6679 - val_accuracy: 0.6964
# Epoch 24/40
# 17/17 [==============================] - 1s 33ms/step - loss: 0.4425 - accuracy: 0.8321 - val_loss: 0.6768 - val_accuracy: 0.7107
# Epoch 25/40
# 17/17 [==============================] - 1s 30ms/step - loss: 0.4136 - accuracy: 0.8357 - val_loss: 0.6878 - val_accuracy: 0.7071
# Epoch 25: early stopping

# %% [markdown]
# # Validação do modelo
#
# Existem duas métricas importantes que devemos analisar após executar a rede neural, o valor de erro observado e o valor de acurácia por épocas de processamento. Uma boa prática é analisarmos com gráficos de linhas para identificarmos as tendências da performance da rede.

# %%
# Validação o erro por épocas
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid(True)
plt.show()

# %%
# Validação da acurácia por épocas
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# Show! Agora vamos armazenar as predições da base de teste na variável de predição **cnn_pred_cat_dog**:

# %%
# Armazena as predicações do modelo dos dados de teste em uma variável
cnn_pred_cat_dog = model.predict(x_test)
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %% [markdown]
# Em seguida, vamos utilizar o argmax do numpy para encontrar a classe com a maior probabilidade prevista para cada amostra. (Lembrando que utilizamos a softmax)

# %%
# Define o índice do valor máximo do modelo de previsão para uma variável
# O valor máximo indica o caractere de previsão do modelo que a imagem representa
cnn_pred_cat_dog = np.argmax(cnn_pred_cat_dog,axis=1)

# Define uma variável para armazenar o rótulo que representa o resultado verdadeiro
y_true = np.argmax(y_test_tf,axis=1)

# %% [markdown]
# Agora vamos organizar os nomes dos animais (gatinhos e cachorrinhos) em uma variável, a fim de criar uma lista única de nomes de animais, ordenados alfabeticamente. Vamos também remover duplicatas e ordenar os nomes em ordem alfabética, resultando em uma lista única, limpa e ordenada de nomes de animais.

# %%
# Cria um array de nomes de caracteres igual ao array de labels
animal_names = labels
# Reduza os nomes dos animais para apenas valores dict únicos
animal_names = list(dict.fromkeys(animal_names))
# Ordena os caracteres em ordem alfabética, qual é a ordem em que os dados são alimentados
animal_names = sorted(animal_names)

# %% [markdown]
# Importante analisar o escopo das classes, então vamos utilizar o classification_report e analisar os resultados por escopo das variáveis targets.

# %%
# Criando a matriz de confusão
cnn_cm_cat_dog = metrics.confusion_matrix(y_true, cnn_pred_cat_dog)
# Definindo a acurácia
cnn_accuracy_cat_dog = metrics.accuracy_score(y_true, cnn_pred_cat_dog)

# Print do classification report
print(metrics.classification_report(y_true, cnn_pred_cat_dog, target_names=animal_names))
# Print da acurácia
print("Accuracy score: {}".format(cnn_accuracy_cat_dog))
# Out:
#               precision    recall  f1-score   support
#
#   cachorinho       0.76      0.66      0.70       140
#      gatinho       0.70      0.79      0.74       140
#
#     accuracy                           0.73       280
#    macro avg       0.73      0.72      0.72       280
# weighted avg       0.73      0.72      0.72       280
#
# Accuracy score: 0.725

# %% [markdown]
# Por fim, vamos criar uma função para adivinhar os animaizinhos?

# %%
#Função para adivinhar o animal
def guess_animal(filepath):
    # Converte o caminho do arquivo para uma imagem
    image = cv2.imread(filepath)
    # Redimensione a imagem e normalize o intervalo de pixels para ficar entre 0 e 1
    img = cv2.resize(image, (image_size, image_size)).astype('float32') / 255.0
    # Expandir a forma do array de imagens
    img = np.expand_dims(img, axis=0)
    # Usando o modelo para prever o animal que representa a imagem
    pred = model.predict(img)
    # Definindo uma variável para armazenar o índice que representa o caractere que representa a imagem
    classes=np.argmax(pred,axis=1)
    # Print no nome do animal previsto
    print(animal_names[classes[0]])
    # Plote a imagem do animal
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # Desliga o eixo de plotagem
    plt.axis('off')

# %% [markdown]
# # Testando o modelo!! 🐱🐶
#
# Chegou o momento de validarmos se essa rede neural consegue realmente identificar novas imagens de cachorros e gatos.

# %%
guess_animal('Teste imagens cães e gatos/cat.202.jpg')
# Out:
# 1/1 [==============================] - 0s 11ms/step
# gatinho

# %%
guess_animal('Teste imagens cães e gatos/cat.475.jpg')
# Out:
# 1/1 [==============================] - 0s 12ms/step
# gatinho

# %%
guess_animal('Teste imagens cães e gatos/dog.30.jpg')
# Out:
# 1/1 [==============================] - 0s 12ms/step
# cachorinho
